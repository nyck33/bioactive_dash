# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
# Out:
# <style>.container {width:100% !important;}</style>

# %% [markdown]
# # How to Calculate the flavonol content
#
# CmpdVal (Aglycone) = Rptd_CmpdVal (glycoside) * Conv_Factor_G
#
# ### if Conv_Factor_SpGr is not NULL
#
# CmpdVal (Aglycone) = Rptd_CmpdVal (glycoside) * Conv_Factor_G /
# Conv_Factor_SpG
# |

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
from os.path import basename


# base url for csv links
base="https://www.nal.usda.gov/sites/www.nal.usda.gov/files/"
url = requests.get("https://www.nal.usda.gov/fnic/nutrient-lists-standard-reference-legacy-2018").text
soup = BeautifulSoup(url)
# check the urls for csv links
links_arr = []
for a in soup.select("a[href]"):
    if 'csv' in a:
        print(a["href"])
        link = a["href"]
        
        links_arr.append(link)
        req = requests.get(link)
        url_content = req.text
        #decoded_content = url_content.decode('utf-8')
        
        csv_name = basename(link)
        file_path = "nutrient_name_csvs/" + csv_name
        with open(file_path, 'w') as f:
            f.writelines(url_content)
        
        f.close()
        #print(url_content)
        
#for link in (urljoin())
# Out:
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/carbohydrate.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/polyunsat_fat.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/protein.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/sat_fat.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/total_dietary_fiber.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/total_sugar.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/Total_Kcal.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/calcium.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/fluoride.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/iron.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/magnesium.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/manganese.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/phosphorus.csv
# https://www.nal.usda.gov/sites/www.nal.usda.gov/files/potassium.csv
# ...

# %%
import glob
file_names = glob.glob("nutrient_name_csvs/*.csv")
#print(file_names[:5])
nutrient_names_arr =  []
for name in file_names:
    csv_name = name.split("/")[1]
    nutrient = csv_name.replace(".csv", "")
    print(nutrient)
    nutrient_names_arr.append(nutrient)
# Out:
# carbohydrate
# lutein_zeaxanthin
# vitamin_b6
# cholesterol
# zinc
# vitamin_diu
# polyunsat_fat
# epa
# niacin
# folate
# leucine
# calcium
# lycopene
# protein
# vitamin_c
# pantothenic_acid
# selenium
# manganese
# vitamin_b12
# vitamin_k
# magnesium
# caffeine
# vitamin_d2
# fluoride
# sat_fat
# iron
# total_sugar
# sodium
# cryptoxanthin
# Total_Kcal
# vitamin_e
# potassium
# phosphorus
# total_dietary_fiber
# choline
# riboflavin

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_arr = []
for file in file_names:
    temp_df = pd.read_csv(file, skiprows=[0])
    df_arr.append(temp_df)
df_dict = dict(zip(nutrient_names_arr, df_arr))

# %%
for k,v in df_dict.items():
    print(f'{k}\n: {v.head()}')
# Out:
# carbohydrate
# :                                          Description           Measure  \
# 0  Syrups, table blends, pancake, with 2% maple, ...          1.0 cups
# 1                      Syrups, table blends, pancake          1.0 cups
# 2  Rice, white, long-grain, regular, raw, unenriched          1.0 cups
# 3                     Beans, pink, mature seeds, raw          1.0 cups
# 4  Desserts, mousse, chocolate, prepared-from-recipe  1.0 recipe yield
#
#    Carbohydrate, by difference(g)Per Measure
# 0                                     219.24
# 1                                     193.02
# 2                                     147.91
# 3                                     134.80
# 4                                     129.85
# lutein_zeaxanthin
# :                                          Description            Measure  \
# 0  Spinach, canned, regular pack, solids and liquids           1.0 cups
# 1  Turnip greens, frozen, cooked, boiled, drained...           1.0 cups
# ...

# %%
#connect to mysql
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:tennis33@localhost/dashcnf?charset=utf8mb4")

# %%
test_df = df_dict['protein']
#print(test_df.columns.tolist())
#print(test_df.head())
test_df.to_sql('protein_foods', con=engine, if_exists='replace', chunksize=1000, index=False)

# %%
for nutrient_name,df in df_dict.items():
    table_name = nutrient_name + "_foods"
    df.to_sql(table_name, con=engine, if_exists='replace', chunksize=1000, index=False)

# %% [markdown]
# # Do the Flavonoid Content csv's from USDA from .accdb file

# %%
#connect to mysql
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:tennis33@localhost/dashcnf?charset=utf8mb4")

# %%
#upload all phytonutrient tables? or select few?
import glob
import pandas as pd
file_names = glob.glob("usdaDBFlavonoidContentSelFoods/*.csv")
df_arr = []
for name in file_names:
    df = pd.read_csv(name)
    #print(f'{df.columns}:\n{df.head()}')
    df_arr.append(df)
    
#get only the filename from path
csv_names_arr = []
for file in file_names:
    csv_name = file.split("/")[1]
    print(csv_name)
    csv_names_arr.append(csv_name)


df_dict = dict(zip(csv_names_arr, df_arr))
# Out:
# FLAV_DAT.csv
# FD_GROUP.csv
# FLAV_IND.csv
# NUTR_DEF.csv
# FOOD_DES.csv

# %%
print(len(df_dict))
for k,v in df_dict.items():
    print(f'{k}: {v.columns}')
# Out:
# 5
# FLAV_DAT.csv: Index(['NDB_No', 'Nutr_no', 'Flav_Val', 'SE', 'n', 'Min', 'Max', 'CC'], dtype='object')
# FD_GROUP.csv: Index(['FdGrp_CD', 'FdGrp_Desc'], dtype='object')
# FLAV_IND.csv: Index(['NDB_No', 'DataSrc ID', 'Food No', 'FoodIndiv_Desc', 'Method',
#        'Cmpd_Name', 'Rptd CmpdVal', 'Rptd_Std Dev', 'Num_Data_Pts', 'LT',
#        'Rptd_Units', 'Fresh Dry_Wt', 'Quant_Std', 'Conv_Factor_G',
#        'Conv_Factor_M', 'Conv_Factor_SpGr', 'Cmpd_Val', 'Cmpt_StdDev'],
#       dtype='object')
# NUTR_DEF.csv: Index(['Nutr_no', 'Nutrient name', 'Flav_Class', 'Tagname', 'Unit'], dtype='object')
# FOOD_DES.csv: Index(['NDB_No', 'FdGrp_Cd', 'Long_Desc', 'SciName'], dtype='object')

# %%
for tbl_name,df in df_dict.items():
    table_name = "FLAV_" + tbl_name 
    df.to_sql(table_name, con=engine, if_exists='replace', chunksize=1000, index=False)
