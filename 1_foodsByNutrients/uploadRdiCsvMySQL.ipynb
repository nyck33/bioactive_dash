# %% [markdown]
# # RDI tables in MySQL are of type float64

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important;}</style>"))
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# <style>.container {width:100% !important;}</style>

# %%
from sqlalchemy import create_engine
rdi_engine = create_engine("mysql+pymysql://root:tennis33@localhost/rdi_db?charset=utf8mb4")

# %%
import glob
filenames_arr = glob.glob('rdi_csv/*csv')
print(filenames_arr)
names_arr = [x.split("/")[1].replace(".csv", "") for x in filenames_arr]
print(names_arr)
# Out:
# ['rdi_csv/elements_upper_rdi.csv', 'rdi_csv/vitamins_upper_rdi.csv', 'rdi_csv/macronutrients_rdi.csv', 'rdi_csv/elements_rdi.csv', 'rdi_csv/macronutrients_dist_range.csv', 'rdi_csv/vitamins_rdi.csv']
# ['elements_upper_rdi', 'vitamins_upper_rdi', 'macronutrients_rdi', 'elements_rdi', 'macronutrients_dist_range', 'vitamins_rdi']

# %%
import pandas as pd
df_arr = [pd.read_csv(x) for x in filenames_arr]
df_dict = dict(zip(names_arr, df_arr))
for k,v in df_dict.items():
    print(f'{k}\n{v}')
# Out:
# elements_upper_rdi
#    Life-Stage Group    Arsenic Boron (mg/d) Calcium (mg/d)   Chromium  \
# 0           Infants    Infants      Infants        Infants    Infants
# 1            < 6 mo         ND           ND           1000         ND
# 2           < 12 mo         ND           ND           1500         ND
# 3          Children   Children     Children       Children   Children
# 4          1 to 3 y         ND            3           2500         ND
# 5          4 to 8 y         ND            6           2500         ND
# 6             Males      Males        Males          Males      Males
# 7         9 to 13 y         ND           11           3000         ND
# 8        14 to 18 y         ND           17          3 000         ND
# 9        19 to 30 y         ND           20           2500         ND
# 10       31 to 50 y         ND           20           2500         ND
# 11         51 to 70         ND           20           2000         ND
# 12           > 70 y         ND           20           2000         ND
# 13          Females    Females      Females        Females    Females
# 14        9 to 13 y         ND           11           3000         ND
# 15       14 to 18 y         ND           17           3000         ND
# 16       19 to 30 y         ND           20           2500         ND
# 17       31 to 50 y         ND           20           2500         ND
# 18       51 to 70 y         ND           20           2000         ND
# 19           > 70 y         ND           20           2000         ND
# 20        Pregnancy  Pregnancy    Pregnancy      Pregnancy  Pregnancy
# 21       14 to 18 y         ND           17           3000         ND
# 22       19 to 30 y         ND           20           2500         ND
# 23       31 to 50 y         ND           20           2500         ND
# 24         Lacation  Lactation    Lactation      Lactation  Lactation
# 25       14 to 18 y         ND           17           3000         ND
# 26       19 to 30 y         ND           20           2500         ND
# 27       31 to 50 y         ND           20           2500         ND
#
#    Copper (ug/d) Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0        Infants         Infants       Infants     Infants          Infants
# 1             ND             0.7            ND          40               ND
# 2             ND             0.9            ND          40               ND
# 3       Children        Children      Children    Children         Children
# 4           1000             1.3           200          40               65
# 5           3000             2.2           300          40              110
# 6          Males           Males         Males       Males            Males
# 7           5000              10           600          40              350
# 8          8 000              10           900          45              350
# 9          10000              10          1100          45              350
# 10         10000              10          1100          45              350
# 11         10000              10          1100          45              350
# 12         10000              10          1100          45              350
# 13       Females         Females       Females     Females          Females
# 14          5000              10           600          40              350
# 15          8000              10           900          45              350
# 16         10000              10          1100          45              350
# 17         10000              10          1100          45              350
# 18         10000              10          1100          45              350
# 19         10000              10          1100          45              350
# 20     Pregnancy       Pregnancy     Pregnancy   Pregnancy        Pregnancy
# 21          8000              10           900          45              350
# 22         10000              10          1100          45              350
# 23         10000              10          1100          45              350
# 24     Lactation       Lactation     Lactation   Lactation        Lactation
# 25          8000              10           900          45              350
# 26         10000              10          1100          45              350
# 27         10000              10          1100          45              350
#
#    Manganese (mg/d) Molybdenum (ug/d) Nickel (mg/d) Phosphorus (g/d)  \
# 0           Infants           Infants       Infants          Infants
# 1                ND                ND            ND               ND
# 2                ND                ND            ND               ND
# 3          Children          Children      Children         Children
# 4                 2               300           0.2                3
# 5                 3               600           0.3                3
# 6             Males             Males         Males            Males
# 7                 6              1100           0.6                4
# 8                 9             1 700           1.0                4
# 9                11              2000           1.0                4
# 10               11              2000           1.0                4
# 11               11              2000           1.0                4
# 12               11              2000           1.0                3
# 13          Females           Females       Females          Females
# 14                6              1100           0.6                4
# 15                9              1700           1.0                4
# 16               11              2000           1.0                4
# 17               11              2000           1.0                4
# 18               11              2000           1.0                4
# 19               11              2000           1.0                3
# 20        Pregnancy         Pregnancy     Pregnancy        Pregnancy
# 21                9              1700           1.0              3.5
# 22               11              2000           1.0              3.5
# 23               11              2000           1.0              3.5
# 24        Lactation         Lactation     Lactation        Lactation
# 25                9              1700           1.0                4
# 26               11              2000           1.0                4
# 27               11              2000           1.0                4
#
#     Potassium Selenium (ug/d)    Silicon    Sulfate Vanadium (mg/d)  \
# 0     Infants         Infants    Infants    Infants         Infants
# 1          ND              45         ND         ND              ND
# 2          ND              60         ND         ND              ND
# 3    Children        Children   Children   Children        Children
# 4          ND              90         ND         ND              ND
# 5          ND             150         ND         ND              ND
# 6       Males           Males      Males      Males           Males
# 7          ND             280         ND         ND              ND
# 8          ND             400         ND         ND              ND
# 9          ND             400         ND         ND             1.8
# 10         ND             400         ND         ND             1.8
# 11         ND             400         ND         ND             1.8
# 12         ND             400         ND         ND             1.8
# 13    Females         Females    Females    Females         Females
# 14         ND             280         ND         ND              ND
# 15         ND             400         ND         ND              ND
# 16         ND             400         ND         ND             1.8
# 17         ND             400         ND         ND             1.8
# 18         ND             400         ND         ND             1.8
# 19         ND             400         ND         ND             1.8
# 20  Pregnancy       Pregnancy  Pregnancy  Pregnancy       Pregnancy
# 21         ND             400         ND         ND              ND
# 22         ND             400         ND         ND              ND
# 23         ND             400         ND         ND              ND
# 24  Lactation       Lactation  Lactation  Lactation       Lactation
# 25         ND             400         ND         ND              ND
# 26         ND             400         ND         ND              ND
# 27         ND             400         ND         ND              ND
#
#    Zinc (mg/d)     Sodium Chloride (g/d)
# 0      Infants    Infants        Infants
# 1            4         ND             ND
# 2            5         ND             ND
# 3     Children   Children       Children
# 4            7         ND            2.3
# 5           12         ND            2.9
# 6        Males      Males          Males
# 7           23         ND            3.4
# 8           34         ND            3.6
# 9           40         ND            3.6
# 10          40         ND            3.6
# 11          40         ND            3.6
# 12          40         ND            3.6
# 13     Females    Females        Females
# 14          23         ND            3.4
# 15          34         ND            3.6
# 16          40         ND            3.6
# 17          40         ND            3.6
# 18          40         ND            3.6
# 19          40         ND            3.6
# 20   Pregnancy  Pregnancy      Pregnancy
# 21          34         ND            3.6
# 22          40         ND            3.6
# 23          40         ND            3.6
# 24   Lactation  Lactation      Lactation
# 25          34         ND            3.6
# 26          40         ND            3.6
# 27          40         ND            3.6
# vitamins_upper_rdi
#    Life-Stage Group  Vitamin A (ug/d) Vitamin C (mg/d)  Vitamin D (ug/d)  \
# 0           Infants               NaN              NaN               NaN
# 1            < 6 mo             600.0               ND              25.0
# 2           < 12 mo             600.0               ND              38.0
# 3          Children               NaN              NaN               NaN
# 4          1 to 3 y             600.0              400              63.0
# 5          4 to 8 y             900.0              650              75.0
# 6             Males               NaN              NaN               NaN
# 7         9 to 13 y            1700.0             1200             100.0
# 8        14 to 18 y            2800.0             1800             100.0
# 9        19 to 30 y            3000.0             2000             100.0
# 10       31 to 50 y            3000.0             2000             100.0
# 11         51 to 70            3000.0             2000             100.0
# 12           > 70 y            3000.0             2000             100.0
# 13          Females               NaN              NaN               NaN
# 14        9 to 13 y            1700.0             1200             100.0
# 15       14 to 18 y            2800.0             1800             100.0
# 16       19 to 30 y            3000.0             2000             100.0
# 17       31 to 50 y            3000.0             2000             100.0
# 18       51 to 70 y            3000.0             2000             100.0
# 19           > 70 y            3000.0             2000             100.0
# 20        Pregnancy               NaN              NaN               NaN
# 21       14 to 18 y            2800.0             1800             100.0
# 22       19 to 30 y            3000.0             2000             100.0
# 23       31 to 50 y            3000.0             2000             100.0
# 24         Lacation               NaN              NaN               NaN
# 25       14 to 18 y            2800.0             1800             100.0
# 26       19 to 30 y            3000.0             2000             100.0
# 27       31 to 50 y            3000.0             2000             100.0
#
#    Vitamin E (mg/d) Vitamin K (ug/d) Thiamin (mg/d) Riboflavin (mg/d)  \
# 0               NaN              NaN            NaN               NaN
# 1                ND               ND             ND                ND
# 2                ND               ND             ND                ND
# 3               NaN              NaN            NaN               NaN
# 4               200               ND             ND                ND
# 5               300               ND             ND                ND
# 6               NaN              NaN            NaN               NaN
# 7               600               ND             ND                ND
# 8               800               ND             ND                ND
# 9              1000               ND             ND                ND
# 10             1000               ND             ND                ND
# 11             1000               ND             ND                ND
# 12             1000               ND             ND                ND
# 13              NaN              NaN            NaN               NaN
# 14              600               ND             ND                ND
# 15              800               ND             ND                ND
# 16             1000               ND             ND                ND
# 17             1000               ND             ND                ND
# 18             1000               ND             ND                ND
# 19             1000               ND             ND                ND
# 20              NaN              NaN            NaN               NaN
# 21              800               ND             ND                ND
# 22             1000               ND             ND                ND
# 23             1000               ND             ND                ND
# 24              NaN              NaN            NaN               NaN
# 25              800               ND             ND                ND
# 26             1000               ND             ND                ND
# 27             1000               ND             ND                ND
#
#    Niacin (mg/d) Vitamin B6 (mg/d) Folate (ug/d) Vitamin B12 (ug/d)  \
# 0            NaN               NaN           NaN                NaN
# 1             ND                ND            ND                 ND
# 2             ND                ND            ND                 ND
# 3            NaN               NaN           NaN                NaN
# 4             10                30           300                 ND
# 5             15                40           400                 ND
# 6            NaN               NaN           NaN                NaN
# 7             20                60           600                 ND
# 8             30                80           800                 ND
# 9             35               100          1000                 ND
# 10            35               100          1000                 ND
# 11            35               100          1000                 ND
# 12            35               100          1000                 ND
# 13           NaN               NaN           NaN                NaN
# 14            20                60           600                 ND
# 15            30                80           800                 ND
# 16            35               100          1000                 ND
# 17            35               100          1000                 ND
# 18            35               100          1000                 ND
# 19            35               100          1000                 ND
# 20           NaN               NaN           NaN                NaN
# 21            30                80           800                 ND
# 22            35               100          1000                 ND
# 23            35               100          1000                 ND
# 24           NaN               NaN           NaN                NaN
# 25            30                80           800                 ND
# 26            35               100          1000                 ND
# 27            35               100          1000                 ND
#
#    Pantothenic Acid (mg/d) Biotin (ug/d) Choline (mg/d) Carotenoids
# 0                      NaN           NaN            NaN         NaN
# 1                       ND            ND             ND          ND
# 2                       ND            ND             ND          ND
# 3                      NaN           NaN            NaN         NaN
# 4                       ND            ND            1.0          ND
# 5                       ND            ND            1.0          ND
# 6                      NaN           NaN            NaN         NaN
# 7                       ND            ND            2.0          ND
# 8                       ND            ND            3.0          ND
# 9                       ND            ND            3.5          ND
# 10                      ND            ND            3.5          ND
# 11                      ND            ND            3.5          ND
# 12                      ND            ND            3.5          ND
# 13                     NaN           NaN            NaN         NaN
# 14                      ND            ND            2.0          ND
# 15                      ND            ND            3.0          ND
# 16                      ND            ND            3.5          ND
# 17                      ND            ND            3.5          ND
# 18                      ND            ND            3.5          ND
# 19                      ND            ND            3.5          ND
# 20                     NaN           NaN            NaN         NaN
# 21                      ND            ND            3.0          ND
# 22                      ND            ND            3.5          ND
# 23                      ND            ND            3.5          ND
# 24                     NaN           NaN            NaN         NaN
# 25                      ND            ND            3.0          ND
# 26                      ND            ND            3.5          ND
# 27                      ND            ND            3.5          ND
# macronutrients_rdi
#    Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d) Total Fiber (g/d)  \
# 0           Infants                NaN                  NaN               NaN
# 1            < 6 mo                0.7                 60.0                ND
# 2           < 12 mo                0.8                 95.0                ND
# 3          Children                NaN                  NaN               NaN
# 4          1 to 3 y                1.3                130.0                19
# 5          4 to 8 y                1.7                130.0                25
# 6             Males                NaN                  NaN               NaN
# 7         9 to 13 y                2.4                130.0                31
# 8        14 to 18 y                3.3                130.0                38
# 9        19 to 30 y                3.7                130.0                38
# 10       31 to 50 y                3.7                130.0                38
# 11         51 to 70                3.7                130.0                30
# 12           > 70 y                3.7                130.0                30
# 13          Females                NaN                  NaN               NaN
# 14        9 to 13 y                2.1                130.0                26
# 15       14 to 18 y                2.3                130.0                26
# 16       19 to 30 y                2.7                130.0                25
# 17       31 to 50 y                2.7                130.0                25
# 18       51 to 70 y                2.7                130.0                21
# 19           > 70 y                2.7                130.0                21
# 20        Pregnancy                NaN                  NaN               NaN
# 21       14 to 18 y                3.0                175.0                28
# 22       19 to 30 y                3.0                175.0                28
# 23       31 to 50 y                3.0                175.0                28
# 24         Lacation                NaN                  NaN               NaN
# 25       14 to 18 y                3.8                210.0                29
# 26       19 to 30 y                3.8                210.0                29
# 27       31 to 50 y                3.8                210.0                29
#
#    Fat (g/d)  Linoleic Acid (g/d)  alpha-Linolenic Acid (g/d)  Protein (g/d)
# 0        NaN                  NaN                         NaN            NaN
# 1         31                  4.4                         0.5            9.1
# 2         30                  4.6                         0.5           11.0
# 3        NaN                  NaN                         NaN            NaN
# 4         ND                  7.0                         0.7           13.0
# 5         ND                 10.0                         0.9           19.0
# 6        NaN                  NaN                         NaN            NaN
# 7         ND                 12.0                         1.2           34.0
# 8         ND                 16.0                         1.6           52.0
# 9         ND                 17.0                         1.6           56.0
# 10        ND                 17.0                         1.6           56.0
# 11        ND                 14.0                         1.6           56.0
# 12        ND                 14.0                         1.6           56.0
# 13       NaN                  NaN                         NaN            NaN
# 14        ND                 10.0                         1.0           34.0
# 15        ND                 11.0                         1.1           46.0
# 16        ND                 12.0                         1.1           46.0
# 17        ND                 12.0                         1.1           46.0
# 18        ND                 11.0                         1.1           46.0
# 19        ND                 11.0                         1.1           46.0
# 20       NaN                  NaN                         NaN            NaN
# 21        ND                 13.0                         1.4           71.0
# 22        ND                 13.0                         1.4           71.0
# 23        ND                 13.0                         1.4           71.0
# 24       NaN                  NaN                         NaN            NaN
# 25        ND                 13.0                         1.3           71.0
# 26        ND                 13.0                         1.3           71.0
# 27        ND                 13.0                         1.3           71.0
# elements_rdi
#    Life-Stage Group Calcium (mg/d) Chromium (ug/d) Copper (ug/d)  \
# 0           Infants        Infants         Infants       Infants
# 1            < 6 mo            200             0.2           200
# 2           < 12 mo            260             5.5           220
# 3          Children       Children        Children      Children
# 4          1 to 3 y            700              11           340
# 5          4 to 8 y           1000              15           440
# 6             Males          Males           Males         Males
# 7         9 to 13 y           1300              25           700
# 8        14 to 18 y           1300              35           890
# 9        19 to 30 y           1000              35           900
# 10       31 to 50 y           1000              35           900
# 11         51 to 70           1000              30           900
# 12           > 70 y           1200              30           900
# 13          Females        Females         Females       Females
# 14        9 to 13 y           1300              21           700
# 15       14 to 18 y           1300              24           890
# 16       19 to 30 y           1000              25           900
# 17       31 to 50 y           1000              25           900
# 18       51 to 70 y           1200              20           900
# 19           > 70 y           1200              20           900
# 20        Pregnancy      Pregnancy       Pregnancy     Pregnancy
# 21       14 to 18 y           1300              29          1000
# 22       19 to 30 y           1000              30          1000
# 23       31 to 50 y           1000              30          1000
# 24         Lacation      Lactation       Lactation     Lactation
# 25       14 to 18 y           1300              44          1300
# 26       19 to 30 y           1000              45          1300
# 27       31 to 50 y           1000              45          1300
#
#    Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0          Infants       Infants     Infants          Infants
# 1             0.01           110        0.27               30
# 2              0.5           130          11               75
# 3         Children      Children    Children         Children
# 4              0.7            90           7               80
# 5                1            90          10              130
# 6            Males         Males       Males            Males
# 7                2           120           8              240
# 8                3           150          11              410
# 9                4           150           8              400
# 10               4           150           8              420
# 11               4           150           8              420
# 12               4           150           8              420
# 13         Females       Females     Females          Females
# 14               2           120           8              240
# 15               3           150          15              360
# 16               3           150          18              310
# 17               3           150          18              320
# 18               3           150           8              320
# 19               3           150           8              320
# 20       Pregnancy     Pregnancy   Pregnancy        Pregnancy
# 21               3           220          27              400
# 22               3           220          27              350
# 23               3           220          27              360
# 24       Lactation     Lactation   Lactation        Lactation
# 25               3           290          10              360
# 26               3           290           9              310
# 27               3           290           9              320
#
#    Manganese (mg/d) Molybdenum (ug/d) Phosphorus (mg/d) Selenium (ug/d)  \
# 0           Infants           Infants           Infants         Infants
# 1             0.003                 2               100              15
# 2               0.6                 3               275              20
# 3          Children          Children          Children        Children
# 4               1.2                17               460              20
# 5               1.5                22               500              30
# 6             Males             Males             Males           Males
# 7               1.9                34              1250              40
# 8               2.2                43              1250              55
# 9               2.3                45               700              55
# 10              2.3                45               700              55
# 11              2.3                45               700              55
# 12              2.3                45               700              55
# 13          Females           Females           Females         Females
# 14              1.6                34              1250              40
# 15              1.6                43              1250              55
# 16              1.8                45               700              55
# 17              1.8                45               700              55
# 18              1.8                45               700              55
# 19              1.8                45               700              55
# 20        Pregnancy         Pregnancy         Pregnancy       Pregnancy
# 21              2.0                50              1250              60
# 22              2.0                50               700              60
# 23              2.0                50               700              60
# 24        Lactation         Lactation         Lactation       Lactation
# 25              2.6                50              1250              70
# 26              2.6                50               700              70
# 27              2.6                50               700              70
#
#    Zinc (mg/d) Potassium (mg/d) Sodium (mg/d) Chloride (g/d)
# 0      Infants          Infants       Infants        Infants
# 1            2              400           110           0.18
# 2            3              860           370           0.57
# 3     Children         Children      Children       Children
# 4            3             2000           800            1.5
# 5            5             2300          1000            1.9
# 6        Males            Males         Males          Males
# 7            8             2500          1200            2.3
# 8           11             3000          1500            2.3
# 9           11             3400          1500            2.3
# 10          11             3400          1500            2.3
# 11          11             3400          1500            2.0
# 12          11             3400          1500            1.8
# 13     Females          Females       Females        Females
# 14           8             2300          1200            2.3
# 15           9             2300          1500            2.3
# 16           8             2600          1500            2.3
# 17           8             2600          1500            2.3
# 18           8             2600          1500            2.0
# 19           8             2600          1500            1.8
# 20   Pregnancy        Pregnancy     Pregnancy      Pregnancy
# 21          12             2600          1500            2.3
# 22          11             2900          1500            2.3
# 23          11             2900          1500            2.3
# 24   Lactation        Lactation     Lactation      Lactation
# 25          13             2500          1500            2.3
# 26          12             2800          1500            2.3
# 27          12             2800          1500            2.3
# macronutrients_dist_range
#   Life-Stage Group  Fat  Linoleic Acid  α-Linolenic Acid  Carbohydrate  \
# 0     child <= 3 y   30              5               0.6            45
# 1    child <= 18 y   25              5               0.6            45
# 2           adults   20              5               0.6            45
#
#    Protein
# 0        5
# 1       10
# 2       10
# vitamins_rdi
#    Life-Stage Group  Vitamin A (ug/d)  Vitamin C (mg/d)  Vitamin D (ug/d)  \
# 0           Infants               NaN               NaN               NaN
# 1            < 6 mo             400.0              40.0              10.0
# 2           < 12 mo             500.0              50.0              10.0
# 3          Children               NaN               NaN               NaN
# 4          1 to 3 y             300.0              15.0              15.0
# 5          4 to 8 y             400.0              25.0              15.0
# 6             Males               NaN               NaN               NaN
# 7         9 to 13 y             600.0              45.0              15.0
# 8        14 to 18 y             900.0              75.0              15.0
# 9        19 to 30 y             900.0              90.0              15.0
# 10       31 to 50 y             900.0              90.0              15.0
# 11         51 to 70             900.0              90.0              15.0
# 12           > 70 y             900.0              90.0              20.0
# 13          Females               NaN               NaN               NaN
# 14        9 to 13 y             600.0              45.0              15.0
# 15       14 to 18 y             700.0              65.0              15.0
# 16       19 to 30 y             700.0              75.0              15.0
# 17       31 to 50 y             700.0              75.0              15.0
# 18       51 to 70 y             700.0              75.0              15.0
# 19           > 70 y             700.0              75.0              20.0
# 20        Pregnancy               NaN               NaN               NaN
# 21       14 to 18 y             750.0              80.0              15.0
# 22       19 to 30 y             770.0              85.0              15.0
# 23       31 to 50 y             770.0              85.0              15.0
# 24         Lacation               NaN               NaN               NaN
# 25       14 to 18 y            1200.0             115.0              15.0
# 26       19 to 30 y            1300.0             120.0              15.0
# 27       31 to 50 y            1300.0             120.0              15.0
#
#     Vitamin E (mg/d)  Vitamin K (ug/d)  Thiamin (mg/d)  Riboflavin (mg/d)  \
# 0                NaN               NaN             NaN                NaN
# 1                4.0               2.0             0.2                0.3
# 2                5.0               2.5             0.3                0.4
# 3                NaN               NaN             NaN                NaN
# 4                6.0              30.0             0.5                0.5
# 5                7.0              55.0             0.6                0.6
# 6                NaN               NaN             NaN                NaN
# 7               11.0              60.0             0.9                0.9
# 8               15.0              75.0             1.2                1.3
# 9               15.0             120.0             1.2                1.3
# 10              15.0             120.0             1.2                1.3
# 11              15.0             120.0             1.2                1.3
# 12              15.0             120.0             1.2                1.3
# 13               NaN               NaN             NaN                NaN
# 14              11.0              60.0             0.9                0.9
# 15              15.0              75.0             1.0                1.0
# 16              15.0              90.0             1.1                1.1
# 17              15.0              90.0             1.1                1.1
# 18              15.0              90.0             1.1                1.1
# 19              15.0              90.0             1.1                1.1
# 20               NaN               NaN             NaN                NaN
# 21              15.0              75.0             1.4                1.4
# 22              15.0              90.0             1.4                1.4
# 23              15.0              90.0             1.4                1.4
# 24               NaN               NaN             NaN                NaN
# 25              19.0              75.0             1.4                1.6
# 26              19.0              90.0             1.4                1.6
# 27              19.0              90.0             1.4                1.6
#
#     Niacin (mg/d)  Vitamin B6 (mg/d)  Folate (ug/d)  Vitamin B12 (ug/d)  \
# 0             NaN                NaN            NaN                 NaN
# 1             2.0                0.1           65.0                 0.4
# 2             4.0                0.3           80.0                 0.5
# 3             NaN                NaN            NaN                 NaN
# 4             6.0                0.5          150.0                 0.9
# 5             8.0                0.6          200.0                 1.2
# 6             NaN                NaN            NaN                 NaN
# 7            12.0                1.0          300.0                 1.8
# 8            16.0                1.3          400.0                 2.4
# 9            16.0                1.3          400.0                 2.4
# 10           16.0                1.3          400.0                 2.4
# 11           16.0                1.7          400.0                 2.4
# 12           16.0                1.7          400.0                 2.4
# 13            NaN                NaN            NaN                 NaN
# 14           12.0                1.0          300.0                 1.8
# 15           14.0                1.2          400.0                 2.4
# 16           14.0                1.3          400.0                 2.4
# 17           14.0                1.3          400.0                 2.4
# 18           14.0                1.5          400.0                 2.4
# 19           14.0                1.5          400.0                 2.4
# 20            NaN                NaN            NaN                 NaN
# 21           18.0                1.9          600.0                 2.6
# 22           18.0                1.9          600.0                 2.6
# 23           18.0                1.9          600.0                 2.6
# 24            NaN                NaN            NaN                 NaN
# 25           17.0                2.0          500.0                 2.8
# 26           17.0                2.0          500.0                 2.8
# 27           17.0                2.0          500.0                 2.8
#
#     Pantothenic Acid (mg/d)  Biotin (ug/d)  Choline (mg/d)
# 0                       NaN            NaN             NaN
# 1                       1.7            5.0           125.0
# 2                       1.8            6.0           150.0
# 3                       NaN            NaN             NaN
# 4                       2.0            8.0           200.0
# 5                       3.0           12.0           250.0
# 6                       NaN            NaN             NaN
# 7                       4.0           20.0           375.0
# 8                       5.0           25.0           550.0
# 9                       5.0           30.0           550.0
# 10                      5.0           30.0           550.0
# 11                      5.0           30.0           550.0
# 12                      5.0           30.0           550.0
# 13                      NaN            NaN             NaN
# 14                      4.0           20.0           375.0
# 15                      5.0           25.0           400.0
# 16                      5.0           30.0           425.0
# 17                      5.0           30.0           425.0
# 18                      5.0           30.0           425.0
# 19                      5.0           30.0           425.0
# 20                      NaN            NaN             NaN
# 21                      6.0           30.0           450.0
# 22                      6.0           30.0           450.0
# 23                      6.0           30.0           450.0
# 24                      NaN            NaN             NaN
# 25                      7.0           35.0           550.0
# 26                      7.0           35.0           550.0
# 27                      7.0           35.0           550.0

# %%
#upload to mysql
for name,df in df_dict.items():
    df.to_sql(name, con=rdi_engine, if_exists='replace', chunksize=1000, index=False)

# %%
# fix alpha symbol in macronutrients_dist_range
mac_dist_df = df_dict['macronutrients_dist_range']
new_cols = [x.replace("\u03B1", "alpha") for x in mac_dist_df.columns.tolist()]
print(new_cols)
mac_dist_df.columns = new_cols
print(mac_dist_df.columns)
df_dict['macronutrients_dist_range'] = mac_dist_df
#upload
# Out:
# ['Life-Stage Group', 'Fat', 'Linoleic Acid', 'alpha-Linolenic Acid', 'Carbohydrate', 'Protein']
# Index(['Life-Stage Group', 'Fat', 'Linoleic Acid', 'alpha-Linolenic Acid',
#        'Carbohydrate', 'Protein'],
#       dtype='object')

# %%
#upload
mac_dist_df.to_sql('macronutrients_dist_range', con=engine, if_exists='replace', chunksize=1000,
                  index=False)

# %%
#change to type str
for k,df in df_dict.items():
    df_dict[k] = df.astype(str)
for k,v in df_dict.items():
    print(f'{v.dtypes}\n{k}\n{v}')
# Out:
# Life-Stage Group     object
# Arsenic              object
# Boron (mg/d)         object
# Calcium (mg/d)       object
# Chromium             object
# Copper (ug/d)        object
# Fluoride (mg/d)      object
# Iodine (ug/d)        object
# Iron (mg/d)          object
# Magnesium (mg/d)     object
# Manganese (mg/d)     object
# Molybdenum (ug/d)    object
# Nickel (mg/d)        object
# Phosphorus (g/d)     object
# Potassium            object
# Selenium (ug/d)      object
# Silicon              object
# Sulfate              object
# Vanadium (mg/d)      object
# Zinc (mg/d)          object
# Sodium               object
# Chloride (g/d)       object
# dtype: object
# elements_upper_rdi
#    Life-Stage Group Arsenic Boron (mg/d) Calcium (mg/d) Chromium  \
# 0           Infants     nan          nan            nan      nan
# 1            < 6 mo     nan          nan         1000.0      nan
# 2           < 12 mo     nan          nan         1500.0      nan
# 3          Children     nan          nan            nan      nan
# 4          1 to 3 y     nan          3.0         2500.0      nan
# 5          4 to 8 y     nan          6.0         2500.0      nan
# 6             Males     nan          nan            nan      nan
# 7         9 to 13 y     nan         11.0         3000.0      nan
# 8        14 to 18 y     nan         17.0            3.0      nan
# 9        19 to 30 y     nan         20.0         2500.0      nan
# 10       31 to 50 y     nan         20.0         2500.0      nan
# 11         51 to 70     nan         20.0         2000.0      nan
# 12           > 70 y     nan         20.0         2000.0      nan
# 13          Females     nan          nan            nan      nan
# 14        9 to 13 y     nan         11.0         3000.0      nan
# 15       14 to 18 y     nan         17.0         3000.0      nan
# 16       19 to 30 y     nan         20.0         2500.0      nan
# 17       31 to 50 y     nan         20.0         2500.0      nan
# 18       51 to 70 y     nan         20.0         2000.0      nan
# 19           > 70 y     nan         20.0         2000.0      nan
# 20        Pregnancy     nan          nan            nan      nan
# 21       14 to 18 y     nan         17.0         3000.0      nan
# 22       19 to 30 y     nan         20.0         2500.0      nan
# 23       31 to 50 y     nan         20.0         2500.0      nan
# 24         Lacation     nan          nan            nan      nan
# 25       14 to 18 y     nan         17.0         3000.0      nan
# 26       19 to 30 y     nan         20.0         2500.0      nan
# 27       31 to 50 y     nan         20.0         2500.0      nan
#
#    Copper (ug/d) Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0            nan             nan           nan         nan              nan
# 1            nan             0.7           nan        40.0              nan
# 2            nan             0.9           nan        40.0              nan
# 3            nan             nan           nan         nan              nan
# 4         1000.0             1.3         200.0        40.0             65.0
# 5         3000.0             2.2         300.0        40.0            110.0
# 6            nan             nan           nan         nan              nan
# 7         5000.0            10.0         600.0        40.0            350.0
# 8            8.0            10.0         900.0        45.0            350.0
# 9        10000.0            10.0        1100.0        45.0            350.0
# 10       10000.0            10.0        1100.0        45.0            350.0
# 11       10000.0            10.0        1100.0        45.0            350.0
# 12       10000.0            10.0        1100.0        45.0            350.0
# 13           nan             nan           nan         nan              nan
# 14        5000.0            10.0         600.0        40.0            350.0
# 15        8000.0            10.0         900.0        45.0            350.0
# 16       10000.0            10.0        1100.0        45.0            350.0
# 17       10000.0            10.0        1100.0        45.0            350.0
# 18       10000.0            10.0        1100.0        45.0            350.0
# 19       10000.0            10.0        1100.0        45.0            350.0
# 20           nan             nan           nan         nan              nan
# 21        8000.0            10.0         900.0        45.0            350.0
# 22       10000.0            10.0        1100.0        45.0            350.0
# 23       10000.0            10.0        1100.0        45.0            350.0
# 24           nan             nan           nan         nan              nan
# 25        8000.0            10.0         900.0        45.0            350.0
# 26       10000.0            10.0        1100.0        45.0            350.0
# 27       10000.0            10.0        1100.0        45.0            350.0
#
#     ... Nickel (mg/d) Phosphorus (g/d) Potassium Selenium (ug/d) Silicon  \
# 0   ...           nan              nan       nan             nan     nan
# 1   ...           nan              nan       nan            45.0     nan
# 2   ...           nan              nan       nan            60.0     nan
# 3   ...           nan              nan       nan             nan     nan
# 4   ...           0.2              3.0       nan            90.0     nan
# 5   ...           0.3              3.0       nan           150.0     nan
# 6   ...           nan              nan       nan             nan     nan
# 7   ...           0.6              4.0       nan           280.0     nan
# 8   ...           1.0              4.0       nan           400.0     nan
# 9   ...           1.0              4.0       nan           400.0     nan
# 10  ...           1.0              4.0       nan           400.0     nan
# 11  ...           1.0              4.0       nan           400.0     nan
# 12  ...           1.0              3.0       nan           400.0     nan
# 13  ...           nan              nan       nan             nan     nan
# 14  ...           0.6              4.0       nan           280.0     nan
# 15  ...           1.0              4.0       nan           400.0     nan
# 16  ...           1.0              4.0       nan           400.0     nan
# 17  ...           1.0              4.0       nan           400.0     nan
# 18  ...           1.0              4.0       nan           400.0     nan
# 19  ...           1.0              3.0       nan           400.0     nan
# 20  ...           nan              nan       nan             nan     nan
# 21  ...           1.0              3.5       nan           400.0     nan
# 22  ...           1.0              3.5       nan           400.0     nan
# 23  ...           1.0              3.5       nan           400.0     nan
# 24  ...           nan              nan       nan             nan     nan
# 25  ...           1.0              4.0       nan           400.0     nan
# 26  ...           1.0              4.0       nan           400.0     nan
# 27  ...           1.0              4.0       nan           400.0     nan
#
#    Sulfate Vanadium (mg/d) Zinc (mg/d) Sodium Chloride (g/d)
# 0      nan             nan         nan    nan            nan
# 1      nan             nan         4.0    nan            nan
# 2      nan             nan         5.0    nan            nan
# 3      nan             nan         nan    nan            nan
# 4      nan             nan         7.0    nan            2.3
# 5      nan             nan        12.0    nan            2.9
# 6      nan             nan         nan    nan            nan
# 7      nan             nan        23.0    nan            3.4
# 8      nan             nan        34.0    nan            3.6
# 9      nan             1.8        40.0    nan            3.6
# 10     nan             1.8        40.0    nan            3.6
# 11     nan             1.8        40.0    nan            3.6
# 12     nan             1.8        40.0    nan            3.6
# 13     nan             nan         nan    nan            nan
# 14     nan             nan        23.0    nan            3.4
# 15     nan             nan        34.0    nan            3.6
# 16     nan             1.8        40.0    nan            3.6
# 17     nan             1.8        40.0    nan            3.6
# 18     nan             1.8        40.0    nan            3.6
# 19     nan             1.8        40.0    nan            3.6
# 20     nan             nan         nan    nan            nan
# 21     nan             nan        34.0    nan            3.6
# 22     nan             nan        40.0    nan            3.6
# 23     nan             nan        40.0    nan            3.6
# 24     nan             nan         nan    nan            nan
# 25     nan             nan        34.0    nan            3.6
# 26     nan             nan        40.0    nan            3.6
# 27     nan             nan        40.0    nan            3.6
#
# [28 rows x 22 columns]
# Life-Stage Group           object
# Vitamin A (ug/d)           object
# Vitamin C (mg/d)           object
# Vitamin D (ug/d)           object
# Vitamin E (mg/d)           object
# Vitamin K (ug/d)           object
# Thiamin (mg/d)             object
# Riboflavin (mg/d)          object
# Niacin (mg/d)              object
# Vitamin B6 (mg/d)          object
# Folate (ug/d)              object
# Vitamin B12 (ug/d)         object
# Pantothenic Acid (mg/d)    object
# Biotin (ug/d)              object
# Choline (mg/d)             object
# Carotenoids                object
# dtype: object
# vitamins_upper_rdi
#    Life-Stage Group Vitamin A (ug/d) Vitamin C (mg/d) Vitamin D (ug/d)  \
# 0           Infants              nan              nan              nan
# 1            < 6 mo            600.0              nan             25.0
# 2           < 12 mo            600.0              nan             38.0
# 3          Children              nan              nan              nan
# 4          1 to 3 y            600.0            400.0             63.0
# 5          4 to 8 y            900.0            650.0             75.0
# 6             Males              nan              nan              nan
# 7         9 to 13 y           1700.0           1200.0            100.0
# 8        14 to 18 y           2800.0           1800.0            100.0
# 9        19 to 30 y           3000.0           2000.0            100.0
# 10       31 to 50 y           3000.0           2000.0            100.0
# 11         51 to 70           3000.0           2000.0            100.0
# 12           > 70 y           3000.0           2000.0            100.0
# 13          Females              nan              nan              nan
# 14        9 to 13 y           1700.0           1200.0            100.0
# 15       14 to 18 y           2800.0           1800.0            100.0
# 16       19 to 30 y           3000.0           2000.0            100.0
# 17       31 to 50 y           3000.0           2000.0            100.0
# 18       51 to 70 y           3000.0           2000.0            100.0
# 19           > 70 y           3000.0           2000.0            100.0
# 20        Pregnancy              nan              nan              nan
# 21       14 to 18 y           2800.0           1800.0            100.0
# 22       19 to 30 y           3000.0           2000.0            100.0
# 23       31 to 50 y           3000.0           2000.0            100.0
# 24         Lacation              nan              nan              nan
# 25       14 to 18 y           2800.0           1800.0            100.0
# 26       19 to 30 y           3000.0           2000.0            100.0
# 27       31 to 50 y           3000.0           2000.0            100.0
#
#    Vitamin E (mg/d) Vitamin K (ug/d) Thiamin (mg/d) Riboflavin (mg/d)  \
# 0               nan              nan            nan               nan
# 1               nan              nan            nan               nan
# 2               nan              nan            nan               nan
# 3               nan              nan            nan               nan
# 4             200.0              nan            nan               nan
# 5             300.0              nan            nan               nan
# 6               nan              nan            nan               nan
# 7             600.0              nan            nan               nan
# 8             800.0              nan            nan               nan
# 9            1000.0              nan            nan               nan
# 10           1000.0              nan            nan               nan
# 11           1000.0              nan            nan               nan
# 12           1000.0              nan            nan               nan
# 13              nan              nan            nan               nan
# 14            600.0              nan            nan               nan
# 15            800.0              nan            nan               nan
# 16           1000.0              nan            nan               nan
# 17           1000.0              nan            nan               nan
# 18           1000.0              nan            nan               nan
# 19           1000.0              nan            nan               nan
# 20              nan              nan            nan               nan
# 21            800.0              nan            nan               nan
# 22           1000.0              nan            nan               nan
# 23           1000.0              nan            nan               nan
# 24              nan              nan            nan               nan
# 25            800.0              nan            nan               nan
# 26           1000.0              nan            nan               nan
# 27           1000.0              nan            nan               nan
#
#    Niacin (mg/d) Vitamin B6 (mg/d) Folate (ug/d) Vitamin B12 (ug/d)  \
# 0            nan               nan           nan                nan
# 1            nan               nan           nan                nan
# 2            nan               nan           nan                nan
# 3            nan               nan           nan                nan
# 4           10.0              30.0         300.0                nan
# 5           15.0              40.0         400.0                nan
# 6            nan               nan           nan                nan
# 7           20.0              60.0         600.0                nan
# 8           30.0              80.0         800.0                nan
# 9           35.0             100.0        1000.0                nan
# 10          35.0             100.0        1000.0                nan
# 11          35.0             100.0        1000.0                nan
# 12          35.0             100.0        1000.0                nan
# 13           nan               nan           nan                nan
# 14          20.0              60.0         600.0                nan
# 15          30.0              80.0         800.0                nan
# 16          35.0             100.0        1000.0                nan
# 17          35.0             100.0        1000.0                nan
# 18          35.0             100.0        1000.0                nan
# 19          35.0             100.0        1000.0                nan
# 20           nan               nan           nan                nan
# 21          30.0              80.0         800.0                nan
# 22          35.0             100.0        1000.0                nan
# 23          35.0             100.0        1000.0                nan
# 24           nan               nan           nan                nan
# 25          30.0              80.0         800.0                nan
# 26          35.0             100.0        1000.0                nan
# 27          35.0             100.0        1000.0                nan
#
#    Pantothenic Acid (mg/d) Biotin (ug/d) Choline (mg/d) Carotenoids
# 0                      nan           nan            nan         nan
# 1                      nan           nan            nan         nan
# 2                      nan           nan            nan         nan
# 3                      nan           nan            nan         nan
# 4                      nan           nan            1.0         nan
# 5                      nan           nan            1.0         nan
# 6                      nan           nan            nan         nan
# 7                      nan           nan            2.0         nan
# 8                      nan           nan            3.0         nan
# 9                      nan           nan            3.5         nan
# 10                     nan           nan            3.5         nan
# 11                     nan           nan            3.5         nan
# 12                     nan           nan            3.5         nan
# 13                     nan           nan            nan         nan
# 14                     nan           nan            2.0         nan
# 15                     nan           nan            3.0         nan
# 16                     nan           nan            3.5         nan
# 17                     nan           nan            3.5         nan
# 18                     nan           nan            3.5         nan
# 19                     nan           nan            3.5         nan
# 20                     nan           nan            nan         nan
# 21                     nan           nan            3.0         nan
# 22                     nan           nan            3.5         nan
# 23                     nan           nan            3.5         nan
# 24                     nan           nan            nan         nan
# 25                     nan           nan            3.0         nan
# 26                     nan           nan            3.5         nan
# 27                     nan           nan            3.5         nan
# Life-Stage Group              object
# Total Water (L/d)             object
# Carbohydrates (g/d)           object
# Total Fiber (g/d)             object
# Fat (g/d)                     object
# Linoleic Acid (g/d)           object
# alpha-Linolenic Acid (g/d)    object
# Protein (g/d)                 object
# dtype: object
# macronutrients_rdi
#    Life-Stage Group Total Water (L/d) Carbohydrates (g/d) Total Fiber (g/d)  \
# 0           Infants               nan                 nan               nan
# 1            < 6 mo               0.7                60.0               nan
# 2           < 12 mo               0.8                95.0               nan
# 3          Children               nan                 nan               nan
# 4          1 to 3 y               1.3               130.0              19.0
# 5          4 to 8 y               1.7               130.0              25.0
# 6             Males               nan                 nan               nan
# 7         9 to 13 y               2.4               130.0              31.0
# 8        14 to 18 y               3.3               130.0              38.0
# 9        19 to 30 y               3.7               130.0              38.0
# 10       31 to 50 y               3.7               130.0              38.0
# 11         51 to 70               3.7               130.0              30.0
# 12           > 70 y               3.7               130.0              30.0
# 13          Females               nan                 nan               nan
# 14        9 to 13 y               2.1               130.0              26.0
# 15       14 to 18 y               2.3               130.0              26.0
# 16       19 to 30 y               2.7               130.0              25.0
# 17       31 to 50 y               2.7               130.0              25.0
# 18       51 to 70 y               2.7               130.0              21.0
# 19           > 70 y               2.7               130.0              21.0
# 20        Pregnancy               nan                 nan               nan
# 21       14 to 18 y               3.0               175.0              28.0
# 22       19 to 30 y               3.0               175.0              28.0
# 23       31 to 50 y               3.0               175.0              28.0
# 24         Lacation               nan                 nan               nan
# 25       14 to 18 y               3.8               210.0              29.0
# 26       19 to 30 y               3.8               210.0              29.0
# 27       31 to 50 y               3.8               210.0              29.0
#
#    Fat (g/d) Linoleic Acid (g/d) alpha-Linolenic Acid (g/d) Protein (g/d)
# 0        nan                 nan                        nan           nan
# 1       31.0                 4.4                        0.5           9.1
# 2       30.0                 4.6                        0.5          11.0
# 3        nan                 nan                        nan           nan
# 4        nan                 7.0                        0.7          13.0
# 5        nan                10.0                        0.9          19.0
# 6        nan                 nan                        nan           nan
# 7        nan                12.0                        1.2          34.0
# 8        nan                16.0                        1.6          52.0
# 9        nan                17.0                        1.6          56.0
# 10       nan                17.0                        1.6          56.0
# 11       nan                14.0                        1.6          56.0
# 12       nan                14.0                        1.6          56.0
# 13       nan                 nan                        nan           nan
# 14       nan                10.0                        1.0          34.0
# 15       nan                11.0                        1.1          46.0
# 16       nan                12.0                        1.1          46.0
# 17       nan                12.0                        1.1          46.0
# 18       nan                11.0                        1.1          46.0
# 19       nan                11.0                        1.1          46.0
# 20       nan                 nan                        nan           nan
# 21       nan                13.0                        1.4          71.0
# 22       nan                13.0                        1.4          71.0
# 23       nan                13.0                        1.4          71.0
# 24       nan                 nan                        nan           nan
# 25       nan                13.0                        1.3          71.0
# 26       nan                13.0                        1.3          71.0
# 27       nan                13.0                        1.3          71.0
# Life-Stage Group     object
# Calcium (mg/d)       object
# Chromium (ug/d)      object
# Copper (ug/d)        object
# Fluoride (mg/d)      object
# Iodine (ug/d)        object
# Iron (mg/d)          object
# Magnesium (mg/d)     object
# Manganese (mg/d)     object
# Molybdenum (ug/d)    object
# Phosphorus (mg/d)    object
# Selenium (ug/d)      object
# Zinc (mg/d)          object
# Potassium (mg/d)     object
# Sodium (mg/d)        object
# Chloride (g/d)       object
# dtype: object
# elements_rdi
#    Life-Stage Group Calcium (mg/d) Chromium (ug/d) Copper (ug/d)  \
# 0           Infants            nan             nan           nan
# 1            < 6 mo          200.0             0.2         200.0
# 2           < 12 mo          260.0             5.5         220.0
# 3          Children            nan             nan           nan
# 4          1 to 3 y          700.0            11.0         340.0
# 5          4 to 8 y         1000.0            15.0         440.0
# 6             Males            nan             nan           nan
# 7         9 to 13 y         1300.0            25.0         700.0
# 8        14 to 18 y         1300.0            35.0         890.0
# 9        19 to 30 y         1000.0            35.0         900.0
# 10       31 to 50 y         1000.0            35.0         900.0
# 11         51 to 70         1000.0            30.0         900.0
# 12           > 70 y         1200.0            30.0         900.0
# 13          Females            nan             nan           nan
# 14        9 to 13 y         1300.0            21.0         700.0
# 15       14 to 18 y         1300.0            24.0         890.0
# 16       19 to 30 y         1000.0            25.0         900.0
# 17       31 to 50 y         1000.0            25.0         900.0
# 18       51 to 70 y         1200.0            20.0         900.0
# 19           > 70 y         1200.0            20.0         900.0
# 20        Pregnancy            nan             nan           nan
# 21       14 to 18 y         1300.0            29.0        1000.0
# 22       19 to 30 y         1000.0            30.0        1000.0
# 23       31 to 50 y         1000.0            30.0        1000.0
# 24         Lacation            nan             nan           nan
# 25       14 to 18 y         1300.0            44.0        1300.0
# 26       19 to 30 y         1000.0            45.0        1300.0
# 27       31 to 50 y         1000.0            45.0        1300.0
#
#    Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0              nan           nan         nan              nan
# 1             0.01         110.0        0.27             30.0
# 2              0.5         130.0        11.0             75.0
# 3              nan           nan         nan              nan
# 4              0.7          90.0         7.0             80.0
# 5              1.0          90.0        10.0            130.0
# 6              nan           nan         nan              nan
# 7              2.0         120.0         8.0            240.0
# 8              3.0         150.0        11.0            410.0
# 9              4.0         150.0         8.0            400.0
# 10             4.0         150.0         8.0            420.0
# 11             4.0         150.0         8.0            420.0
# 12             4.0         150.0         8.0            420.0
# 13             nan           nan         nan              nan
# 14             2.0         120.0         8.0            240.0
# 15             3.0         150.0        15.0            360.0
# 16             3.0         150.0        18.0            310.0
# 17             3.0         150.0        18.0            320.0
# 18             3.0         150.0         8.0            320.0
# 19             3.0         150.0         8.0            320.0
# 20             nan           nan         nan              nan
# 21             3.0         220.0        27.0            400.0
# 22             3.0         220.0        27.0            350.0
# 23             3.0         220.0        27.0            360.0
# 24             nan           nan         nan              nan
# 25             3.0         290.0        10.0            360.0
# 26             3.0         290.0         9.0            310.0
# 27             3.0         290.0         9.0            320.0
#
#    Manganese (mg/d) Molybdenum (ug/d) Phosphorus (mg/d) Selenium (ug/d)  \
# 0               nan               nan               nan             nan
# 1             0.003               2.0             100.0            15.0
# 2               0.6               3.0             275.0            20.0
# 3               nan               nan               nan             nan
# 4               1.2              17.0             460.0            20.0
# 5               1.5              22.0             500.0            30.0
# 6               nan               nan               nan             nan
# 7               1.9              34.0            1250.0            40.0
# 8               2.2              43.0            1250.0            55.0
# 9               2.3              45.0             700.0            55.0
# 10              2.3              45.0             700.0            55.0
# 11              2.3              45.0             700.0            55.0
# 12              2.3              45.0             700.0            55.0
# 13              nan               nan               nan             nan
# 14              1.6              34.0            1250.0            40.0
# 15              1.6              43.0            1250.0            55.0
# 16              1.8              45.0             700.0            55.0
# 17              1.8              45.0             700.0            55.0
# 18              1.8              45.0             700.0            55.0
# 19              1.8              45.0             700.0            55.0
# 20              nan               nan               nan             nan
# 21              2.0              50.0            1250.0            60.0
# 22              2.0              50.0             700.0            60.0
# 23              2.0              50.0             700.0            60.0
# 24              nan               nan               nan             nan
# 25              2.6              50.0            1250.0            70.0
# 26              2.6              50.0             700.0            70.0
# 27              2.6              50.0             700.0            70.0
#
#    Zinc (mg/d) Potassium (mg/d) Sodium (mg/d) Chloride (g/d)
# 0          nan              nan           nan            nan
# 1          2.0            400.0         110.0           0.18
# 2          3.0            860.0         370.0           0.57
# 3          nan              nan           nan            nan
# 4          3.0              2.0         800.0            1.5
# 5          5.0              2.0           1.0            1.9
# 6          nan              nan           nan            nan
# 7          8.0              2.0           1.0            2.3
# 8         11.0              3.0           1.0            2.3
# 9         11.0              3.0           1.0            2.3
# 10        11.0              3.0           1.0            2.3
# 11        11.0              3.0           1.0            2.0
# 12        11.0              3.0           1.0            1.8
# 13         nan              nan           nan            nan
# 14         8.0              2.0           1.0            2.3
# 15         9.0              2.0           1.0            2.3
# 16         8.0              2.0           1.0            2.3
# 17         8.0              2.0           1.0            2.3
# 18         8.0              2.0           1.0            2.0
# 19         8.0              2.0           1.0            1.8
# 20         nan              nan           nan            nan
# 21        12.0              2.0           1.0            2.3
# 22        11.0              2.0           1.0            2.3
# 23        11.0              2.0           1.0            2.3
# 24         nan              nan           nan            nan
# 25        13.0              2.0           1.0            2.3
# 26        12.0              2.0           1.0            2.3
# 27        12.0              2.0           1.0            2.3
# Life-Stage Group        object
# Fat                     object
# Linoleic Acid           object
# alpha-Linolenic Acid    object
# Carbohydrate            object
# Protein                 object
# dtype: object
# macronutrients_dist_range
#   Life-Stage Group Fat Linoleic Acid alpha-Linolenic Acid Carbohydrate Protein
# 0     child <= 3 y  30             5                  0.6           45       5
# 1    child <= 18 y  25             5                  0.6           45      10
# 2           adults  20             5                  0.6           45      10
# Life-Stage Group           object
# Vitamin A (ug/d)           object
# Vitamin C (mg/d)           object
# Vitamin D (ug/d)           object
# Vitamin E (mg/d)           object
# Vitamin K (ug/d)           object
# Thiamin (mg/d)             object
# Riboflavin (mg/d)          object
# Niacin (mg/d)              object
# Vitamin B6 (mg/d)          object
# Folate (ug/d)              object
# Vitamin B12 (ug/d)         object
# Pantothenic Acid (mg/d)    object
# Biotin (ug/d)              object
# Choline (mg/d)             object
# dtype: object
# vitamins_rdi
#    Life-Stage Group Vitamin A (ug/d) Vitamin C (mg/d) Vitamin D (ug/d)  \
# 0           Infants              nan              nan              nan
# 1            < 6 mo            400.0             40.0             10.0
# 2           < 12 mo            500.0             50.0             10.0
# 3          Children              nan              nan              nan
# 4          1 to 3 y            300.0             15.0             15.0
# 5          4 to 8 y            400.0             25.0             15.0
# 6             Males              nan              nan              nan
# 7         9 to 13 y            600.0             45.0             15.0
# 8        14 to 18 y            900.0             75.0             15.0
# 9        19 to 30 y            900.0             90.0             15.0
# 10       31 to 50 y            900.0             90.0             15.0
# 11         51 to 70            900.0             90.0             15.0
# 12           > 70 y            900.0             90.0             20.0
# 13          Females              nan              nan              nan
# 14        9 to 13 y            600.0             45.0             15.0
# 15       14 to 18 y            700.0             65.0             15.0
# 16       19 to 30 y            700.0             75.0             15.0
# 17       31 to 50 y            700.0             75.0             15.0
# 18       51 to 70 y            700.0             75.0             15.0
# 19           > 70 y            700.0             75.0             20.0
# 20        Pregnancy              nan              nan              nan
# 21       14 to 18 y            750.0             80.0             15.0
# 22       19 to 30 y            770.0             85.0             15.0
# 23       31 to 50 y            770.0             85.0             15.0
# 24         Lacation              nan              nan              nan
# 25       14 to 18 y           1200.0            115.0             15.0
# 26       19 to 30 y           1300.0            120.0             15.0
# 27       31 to 50 y           1300.0            120.0             15.0
#
#    Vitamin E (mg/d) Vitamin K (ug/d) Thiamin (mg/d) Riboflavin (mg/d)  \
# 0               nan              nan            nan               nan
# 1               4.0              2.0            0.2               0.3
# 2               5.0              2.5            0.3               0.4
# 3               nan              nan            nan               nan
# 4               6.0             30.0            0.5               0.5
# 5               7.0             55.0            0.6               0.6
# 6               nan              nan            nan               nan
# 7              11.0             60.0            0.9               0.9
# 8              15.0             75.0            1.2               1.3
# 9              15.0            120.0            1.2               1.3
# 10             15.0            120.0            1.2               1.3
# 11             15.0            120.0            1.2               1.3
# 12             15.0            120.0            1.2               1.3
# 13              nan              nan            nan               nan
# 14             11.0             60.0            0.9               0.9
# 15             15.0             75.0            1.0               1.0
# 16             15.0             90.0            1.1               1.1
# 17             15.0             90.0            1.1               1.1
# 18             15.0             90.0            1.1               1.1
# 19             15.0             90.0            1.1               1.1
# 20              nan              nan            nan               nan
# 21             15.0             75.0            1.4               1.4
# 22             15.0             90.0            1.4               1.4
# 23             15.0             90.0            1.4               1.4
# 24              nan              nan            nan               nan
# 25             19.0             75.0            1.4               1.6
# 26             19.0             90.0            1.4               1.6
# 27             19.0             90.0            1.4               1.6
#
#    Niacin (mg/d) Vitamin B6 (mg/d) Folate (ug/d) Vitamin B12 (ug/d)  \
# 0            nan               nan           nan                nan
# 1            2.0               0.1          65.0                0.4
# 2            4.0               0.3          80.0                0.5
# 3            nan               nan           nan                nan
# 4            6.0               0.5         150.0                0.9
# 5            8.0               0.6         200.0                1.2
# 6            nan               nan           nan                nan
# 7           12.0               1.0         300.0                1.8
# 8           16.0               1.3         400.0                2.4
# 9           16.0               1.3         400.0                2.4
# 10          16.0               1.3         400.0                2.4
# 11          16.0               1.7         400.0                2.4
# 12          16.0               1.7         400.0                2.4
# 13           nan               nan           nan                nan
# 14          12.0               1.0         300.0                1.8
# 15          14.0               1.2         400.0                2.4
# 16          14.0               1.3         400.0                2.4
# 17          14.0               1.3         400.0                2.4
# 18          14.0               1.5         400.0                2.4
# 19          14.0               1.5         400.0                2.4
# 20           nan               nan           nan                nan
# 21          18.0               1.9         600.0                2.6
# 22          18.0               1.9         600.0                2.6
# 23          18.0               1.9         600.0                2.6
# 24           nan               nan           nan                nan
# 25          17.0               2.0         500.0                2.8
# 26          17.0               2.0         500.0                2.8
# 27          17.0               2.0         500.0                2.8
#
#    Pantothenic Acid (mg/d) Biotin (ug/d) Choline (mg/d)
# 0                      nan           nan            nan
# 1                      1.7           5.0          125.0
# 2                      1.8           6.0          150.0
# 3                      nan           nan            nan
# 4                      2.0           8.0          200.0
# 5                      3.0          12.0          250.0
# 6                      nan           nan            nan
# 7                      4.0          20.0          375.0
# 8                      5.0          25.0          550.0
# 9                      5.0          30.0          550.0
# 10                     5.0          30.0          550.0
# 11                     5.0          30.0          550.0
# 12                     5.0          30.0          550.0
# 13                     nan           nan            nan
# 14                     4.0          20.0          375.0
# 15                     5.0          25.0          400.0
# 16                     5.0          30.0          425.0
# 17                     5.0          30.0          425.0
# 18                     5.0          30.0          425.0
# 19                     5.0          30.0          425.0
# 20                     nan           nan            nan
# 21                     6.0          30.0          450.0
# 22                     6.0          30.0          450.0
# 23                     6.0          30.0          450.0
# 24                     nan           nan            nan
# 25                     7.0          35.0          550.0
# 26                     7.0          35.0          550.0
# 27                     7.0          35.0          550.0

# %% [markdown]
# ### Waypoint: connect to Mongo for CNF

# %%
from mongoengine import connect
connect('cnf')
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary())

# %%
from mongo_models import (
    CNFFoodName, CNFConversionFactor, CNFNutrientAmount,
    CNFYieldAmount, CNFRefuseAmount, CNFNutrientName
)

# %%
# test mongo
q='bean'
foods = CNFFoodName.objects.filter(description__icontains=q) if q else []
for food in foods:
    print(food.description, type(food))
# Out:
# Vegetable oil, soybean <class 'mongo_models.CNFFoodName'>
# Vegetable oil, soybean lecithin <class 'mongo_models.CNFFoodName'>
# Shortening, household, soybean (hydrogenated) and palm <class 'mongo_models.CNFFoodName'>
# Shortening, multipurpose, hydrogenated soybean and palm <class 'mongo_models.CNFFoodName'>
# Shortening, industrial, for frying (liquid), soybean <class 'mongo_models.CNFFoodName'>
# Shortening, industrial, for frying (solid), soybean <class 'mongo_models.CNFFoodName'>
# Shortening, industrial, for baking (cake), soybean <class 'mongo_models.CNFFoodName'>
# Shortening, industrial, for baking (pastry), soybean <class 'mongo_models.CNFFoodName'>
# Soup, bean with bacon, canned, condensed <class 'mongo_models.CNFFoodName'>
# Soup, bean with ham, ready-to-serve <class 'mongo_models.CNFFoodName'>
# Soup, bean with bacon, dehydrated <class 'mongo_models.CNFFoodName'>
# Soup, bean with bacon, canned, condensed, water added <class 'mongo_models.CNFFoodName'>
# Soup, bean with bacon, dehydrated, water added <class 'mongo_models.CNFFoodName'>
# Beans, kidney, sprouted, raw <class 'mongo_models.CNFFoodName'>
# Beans, kidney, sprouted, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, lima, raw <class 'mongo_models.CNFFoodName'>
# Beans, lima, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, lima, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, lima (fordhook), frozen, unprepared <class 'mongo_models.CNFFoodName'>
# Beans, lima (fordhook), frozen, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, mung, mature seeds, sprouted, bean sprouts, raw <class 'mongo_models.CNFFoodName'>
# Beans, mung, mature seeds, sprouted, bean sprouts, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, mung, mature seeds, sprouted, bean sprouts, stir-fried, no fat added <class 'mongo_models.CNFFoodName'>
# Beans, navy, mature seeds, sprouted, raw <class 'mongo_models.CNFFoodName'>
# Beans, navy, mature seeds, sprouted, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, pinto, immature seeds, frozen, unprepared <class 'mongo_models.CNFFoodName'>
# Beans, pinto, frozen, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, shellie, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), canned, seasoned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), frozen, unprepared <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), frozen, boiled, drained <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), fresh, raw <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), fresh, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, yardlong, (asparagus bean or cowpea), raw <class 'mongo_models.CNFFoodName'>
# Beans, yardlong, (asparagus bean or cowpea), boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, raw <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, boiled, drained <class 'mongo_models.CNFFoodName'>
# Soybeans, green (edamame), raw <class 'mongo_models.CNFFoodName'>
# Soybeans, green (edamame), boiled, drained <class 'mongo_models.CNFFoodName'>
# Soybeans, mature seeds, sprouted, bean sprouts, raw <class 'mongo_models.CNFFoodName'>
# Soybeans, mature seeds, sprouted, bean sprouts, steamed <class 'mongo_models.CNFFoodName'>
# Soybeans, mature seeds, sprouted, bean sprouts, stir-fried, no fat added <class 'mongo_models.CNFFoodName'>
# Winged beans (goa bean), green, raw <class 'mongo_models.CNFFoodName'>
# Winged beans (goa bean), green, boiled, drained <class 'mongo_models.CNFFoodName'>
# Winged beans (goa bean) leaves, raw <class 'mongo_models.CNFFoodName'>
# Winged beans (goa bean) tuber, raw <class 'mongo_models.CNFFoodName'>
# Yambean (jimaca), tuber, raw <class 'mongo_models.CNFFoodName'>
# Yambean (jimaca), tuber, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, mung, mature seeds, sprouted, bean sprouts, canned, drained <class 'mongo_models.CNFFoodName'>
# Beans, pinto, mature seeds, sprouted, raw <class 'mongo_models.CNFFoodName'>
# Beans, pinto, mature seeds, sprouted, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), frozen, boiled, with salt <class 'mongo_models.CNFFoodName'>
# Beans, snap, yellow, frozen, boiled, with salt <class 'mongo_models.CNFFoodName'>
# Beans, lima, baby, frozen, unprepared <class 'mongo_models.CNFFoodName'>
# Beans, lima, baby, frozen, boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), raw <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), boiled, drained <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), canned, drained solids <class 'mongo_models.CNFFoodName'>
# Soybean kernels, roasted, unsalted <class 'mongo_models.CNFFoodName'>
# Beans, adzuki, raw <class 'mongo_models.CNFFoodName'>
# Beans, adzuki, boiled <class 'mongo_models.CNFFoodName'>
# Beans, adzuki, canned, sweetened <class 'mongo_models.CNFFoodName'>
# Beans, adzuki, yokan (bean jelly) <class 'mongo_models.CNFFoodName'>
# Beans, baked, homemade <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, plain or vegetarian <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, with beef <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, with wieners <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, with pork and sweet sauce <class 'mongo_models.CNFFoodName'>
# Beans, black turtle, mature seeds, raw <class 'mongo_models.CNFFoodName'>
# Beans, black turtle, mature seeds, boiled <class 'mongo_models.CNFFoodName'>
# Beans, black turtle, mature seeds, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, cranberry (roman), raw <class 'mongo_models.CNFFoodName'>
# Beans, cranberry (roman), boiled <class 'mongo_models.CNFFoodName'>
# Beans, french, mature seeds, raw <class 'mongo_models.CNFFoodName'>
# Beans, french, mature seeds, boiled <class 'mongo_models.CNFFoodName'>
# Beans, great northern, raw <class 'mongo_models.CNFFoodName'>
# Beans, great northern, boiled <class 'mongo_models.CNFFoodName'>
# Beans, great northern, canned, solids and liquid, no salt added <class 'mongo_models.CNFFoodName'>
# Beans, kidney, light red, boiled <class 'mongo_models.CNFFoodName'>
# Beans, kidney, dark red, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, navy, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, pink, raw <class 'mongo_models.CNFFoodName'>
# Beans, pink, boiled <class 'mongo_models.CNFFoodName'>
# Beans, pinto, raw <class 'mongo_models.CNFFoodName'>
# Beans, pinto, boiled <class 'mongo_models.CNFFoodName'>
# Beans, pinto, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, small white, raw <class 'mongo_models.CNFFoodName'>
# Beans, small white, boiled <class 'mongo_models.CNFFoodName'>
# Beans, yellow, raw <class 'mongo_models.CNFFoodName'>
# Beans, yellow, boiled <class 'mongo_models.CNFFoodName'>
# Beans, white, canned, solids and liquid, no salt added <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, raw <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, boiled <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, large, raw <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, large, boiled <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, large, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, baby, raw <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, baby, boiled <class 'mongo_models.CNFFoodName'>
# Moth beans, raw <class 'mongo_models.CNFFoodName'>
# Moth beans, boiled <class 'mongo_models.CNFFoodName'>
# Beans, legumes, mung (green gram), raw <class 'mongo_models.CNFFoodName'>
# Beans, legumes, mung (green gram), boiled <class 'mongo_models.CNFFoodName'>
# Beans, mung, long rice (chinese noodles), dehydrated <class 'mongo_models.CNFFoodName'>
# Beans, mungo, raw <class 'mongo_models.CNFFoodName'>
# Beans, mungo, boiled <class 'mongo_models.CNFFoodName'>
# Refried beans, canned <class 'mongo_models.CNFFoodName'>
# Soybean kernels, roasted, salted <class 'mongo_models.CNFFoodName'>
# Soybeans, dry, roasted <class 'mongo_models.CNFFoodName'>
# Soybean, fermented products, miso <class 'mongo_models.CNFFoodName'>
# Soybean, fermented products, natto <class 'mongo_models.CNFFoodName'>
# Soybean, fermented products, tempeh (tempe) <class 'mongo_models.CNFFoodName'>
# Beans, yardlong, mature seeds, raw <class 'mongo_models.CNFFoodName'>
# Beans, yardlong, mature seeds, boiled <class 'mongo_models.CNFFoodName'>
# Beans, winged (goa beans), dry, raw <class 'mongo_models.CNFFoodName'>
# Beans, winged (goa beans), dry, boiled <class 'mongo_models.CNFFoodName'>
# Beans, adzuki, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, black, mature seeds, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, black turtle, mature seeds, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, cranberry (roman), boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, french, mature seeds, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, great northern, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, kidney, light red, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, pink, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, pinto, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, small white, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, yellow, boiled, salted <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), dry, boiled, with salt <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, large, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, lima, dry, baby, boiled, salted <class 'mongo_models.CNFFoodName'>
# Moth beans, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, legumes, mung (green gram), boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, mungo, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, yardlong, mature seeds, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, winged (goa beans), dry, boiled, with salt <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, with pork <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, with pork and tomato sauce <class 'mongo_models.CNFFoodName'>
# Beans, black, mature seeds, raw <class 'mongo_models.CNFFoodName'>
# Beans, black, mature seeds, boiled <class 'mongo_models.CNFFoodName'>
# Beans, cranberry, canned, with solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, kidney, all types, canned, solids and liquid <class 'mongo_models.CNFFoodName'>
# Beans, kidney, light red, raw <class 'mongo_models.CNFFoodName'>
# Beans, kidney, dark red, raw <class 'mongo_models.CNFFoodName'>
# Beans, kidney, dark red, boiled <class 'mongo_models.CNFFoodName'>
# Beans, navy, raw <class 'mongo_models.CNFFoodName'>
# Beans, navy, boiled <class 'mongo_models.CNFFoodName'>
# Beans, white, raw <class 'mongo_models.CNFFoodName'>
# Beans, white, boiled <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), dry, raw <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), dry, boiled <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), raw <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), boiled <class 'mongo_models.CNFFoodName'>
# Chili with beans, canned <class 'mongo_models.CNFFoodName'>
# Soybeans, dry, raw <class 'mongo_models.CNFFoodName'>
# Soybeans, dry, boiled <class 'mongo_models.CNFFoodName'>
# Beans, kidney, dark red, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, navy, boiled, salted <class 'mongo_models.CNFFoodName'>
# Beans, white, boiled, salted <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), boiled, salted <class 'mongo_models.CNFFoodName'>
# Soybeans, dry, boiled, salted <class 'mongo_models.CNFFoodName'>
# Candies, jellybeans <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans and cheese <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans and chili peppers <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans and beef <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans, cheese and beef <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, burrito with beans, cheese and chili peppers <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, enchirito with cheese, beef and beans <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, frijoles (pinto beans) with cheese <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, nachos with cheese, beans, ground beef and tomatoes <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, tostada with beans and cheese <class 'mongo_models.CNFFoodName'>
# Fast foods, mexican, tostada with beans, beef and cheese <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), in pod, raw <class 'mongo_models.CNFFoodName'>
# Chili con carne with beans, canned <class 'mongo_models.CNFFoodName'>
# Soybean, fermented products, Tempeh (tempe), cooked <class 'mongo_models.CNFFoodName'>
# Candies, dark chocolate coated coffee beans <class 'mongo_models.CNFFoodName'>
# Candies, milk chocolate coated coffee beans <class 'mongo_models.CNFFoodName'>
# Beverage, bean <class 'mongo_models.CNFFoodName'>
# Vegetable oil,  canola and soybean <class 'mongo_models.CNFFoodName'>
# Beans, chili, barbecue, ranch style, cooked <class 'mongo_models.CNFFoodName'>
# Beans, liquid from stewed kidney beans <class 'mongo_models.CNFFoodName'>
# Soybean, curd cheese <class 'mongo_models.CNFFoodName'>
# Beans, baked, canned, no salt added <class 'mongo_models.CNFFoodName'>
# Chili without beans, canned <class 'mongo_models.CNFFoodName'>
# Beans, black, flour <class 'mongo_models.CNFFoodName'>
# Beans, white, flour <class 'mongo_models.CNFFoodName'>
# Soybeans, green (edamame), frozen, unprepared <class 'mongo_models.CNFFoodName'>
# Soybeans, green (edamame), frozen, prepared <class 'mongo_models.CNFFoodName'>
# Burrito, beef and bean, frozen <class 'mongo_models.CNFFoodName'>
# Burrito, bean and cheese, frozen <class 'mongo_models.CNFFoodName'>
# Soup, red pepper and black bean, ready-to-serve, reduced sodium <class 'mongo_models.CNFFoodName'>
# Burrito, bean and cheese, microwaved <class 'mongo_models.CNFFoodName'>
# Burrito, beef and bean, microwaved <class 'mongo_models.CNFFoodName'>
# Beans, kidney, all types, boiled, with salt <class 'mongo_models.CNFFoodName'>
# Beans, kidney, all types, boiled <class 'mongo_models.CNFFoodName'>
# Beans, kidney, all types, raw <class 'mongo_models.CNFFoodName'>
# Beans, kidney, sprouted, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, navy, mature seeds, sprouted, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, pinto, frozen, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, pinto, mature seeds, sprouted,  boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), canned, drained solids, unsalted <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), canned, solids and liquid, unsalted <class 'mongo_models.CNFFoodName'>
# Broadbeans (fava beans), fresh, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, hyacinth, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, lima, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, lima, baby, frozen, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, lima (fordhook), frozen, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Beans, mung, mature seeds, sprouted, bean sprouts, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Salad dressing, mayonnaise, imitation, soybean <class 'mongo_models.CNFFoodName'>
# Soybeans, green (edamame), boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Soybeans, mature seeds, sprouted, bean sprouts, stir-fried, with salt, no fat added <class 'mongo_models.CNFFoodName'>
# Yardlong beans (asparagus bean or cowpea), boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Yambean (jimaca), tuber, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Winged beans (goa bean), green, boiled, drained, with salt <class 'mongo_models.CNFFoodName'>
# Vegetables, asian mix, frozen, boiled, drained (broccoli, green beans, mini corn, snow peas, red pepper) <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), frozen, microwaved <class 'mongo_models.CNFFoodName'>
# Refried beans, canned, vegetarian <class 'mongo_models.CNFFoodName'>
# Beans, snap (Italian, green or yellow), fresh, microwaved <class 'mongo_models.CNFFoodName'>
# Soup, black bean, ready-to-serve <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), canned, drained solids <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), canned, drained, rinsed <class 'mongo_models.CNFFoodName'>
# Beans, kidney, red, canned, drained solids <class 'mongo_models.CNFFoodName'>
# Beans, pinto, canned, drained solids <class 'mongo_models.CNFFoodName'>
# Beans, kidney, red, canned, drained and rinsed <class 'mongo_models.CNFFoodName'>
# Beans, pinto, canned, drained and rinsed <class 'mongo_models.CNFFoodName'>
# Beans, black, mature seeds, canned, solids and liquid, reduced sodium <class 'mongo_models.CNFFoodName'>
# Beans, great northern, canned, solids and liquid, reduced sodium <class 'mongo_models.CNFFoodName'>
# Beans, kidney, red, canned, solids and liquid, reduced sodium <class 'mongo_models.CNFFoodName'>
# Beans, pinto, canned, solids and liquid, reduced sodium <class 'mongo_models.CNFFoodName'>
# Chickpeas (garbanzo beans, bengal gram), canned, solids and liquid, reduced sodium <class 'mongo_models.CNFFoodName'>
# Refried beans, canned, reduced sodium <class 'mongo_models.CNFFoodName'>
# Refried beans <class 'mongo_models.CNFFoodName'>
# Margarine, stick, canola and/or soybean oil <class 'mongo_models.CNFFoodName'>
# Margarine, stick, palm and soybean oils <class 'mongo_models.CNFFoodName'>
# Margarine, tub, non-hydrogenated, soybean oil <class 'mongo_models.CNFFoodName'>
# Margarine-like spread, tub, hydrogenated, canola and soybean oil, 50% fat <class 'mongo_models.CNFFoodName'>
# Babyfood, vegetables, jarred, green beans, all stages <class 'mongo_models.CNFFoodName'>
# Babyfood, vegetables and fruit, jarred, green beans and apple <class 'mongo_models.CNFFoodName'>
# Margarine, tub, hydrogenated, soybean oil <class 'mongo_models.CNFFoodName'>

# %% [markdown]
# ### get nutrients dict from make_meals_callbacks.py and match with RDI,

# %%
from dash_utils.Shiny_utils import (rdi_nutrients, make_food_to_id_dict, get_unit_names,
                                         make_foodgroup_df, make_conversions_df, make_nutrients_df,
                                         get_conversions_multiplier, mult_nutrients_df)
# used in layout for datalist
food_to_id_dict, food_names_arr, food_ids_arr = make_food_to_id_dict()

# dict of cnf nutrient names: nutrient units
nutrients = CNFNutrientName.objects
cnf_nutr_dict = {}
cnf_nutrient_names_all = []
cnf_nutrient_units_all = []
for n in nutrients:
    cnf_nutr_dict[str(n.name)] = str(n.unit)
    cnf_nutrient_names_all.append(str(n.name))
    cnf_nutrient_units_all.append(str(n.unit))

assert len(cnf_nutrient_names_all) == len(cnf_nutrient_units_all)
num_values = len(cnf_nutrient_names_all)
# make a base nutrients dataframe to cumulate into
nuts_totals_dict = {
    "Name": cnf_nutrient_names_all,
    "Value": ["0" for i in range(num_values)], # 0 should be str
    "Units": cnf_nutrient_units_all
}

# %% [markdown]
# # Micro "u" is \xb5     with g tacked on

# %%
# check units
cnf_units_arr = cnf_nutrient_units_all

cnf_units_arr = [x.replace("\xb5g", "ug") for x in cnf_nutrient_units_all]
cnf_units_arr = [x.replace(x, f'{x}/d') for x in cnf_units_arr]
print(len(cnf_units_arr))
print(cnf_units_arr)
# Out:
# 152
# ['g/d', 'g/d', 'g/d', 'g/d', 'kCal/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'mg/d', 'g/d', 'g/d', 'g/d', 'mg/d', 'mg/d', 'kJ/d', 'g/d', 'g/d', 'g/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'ug/d', 'ug/d', 'ug/d', 'ug/d', 'ug/d', 'mg/d', 'IU/d', 'ug/d', 'ug/d', 'ug/d', 'ug/d', 'ug/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'NE/d', 'mg/d', 'mg/d', 'ug/d', 'ug/d', 'ug/d', 'mg/d', 'ug/d', 'ug/d', 'ug/d', 'ug/d', 'mg/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'mg/d', 'mg/d', 'ug/d', 'mg/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'mg/d', 'mg/d', 'mg/d', 'mg/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d', 'g/d']

# %%
#dict of {cnf_nut: cnf_units}
cnf_arr = []
for nut in nuts_totals_dict['Name']:
    cnf_arr.append(nut.lower())
#print(len(cnf_arr))
#print(cnf_arr)
cnf_nuts_dict = dict(zip(cnf_arr, cnf_units_arr))
#for nut, units in cnf_nuts_dict.items():
#for nut, units in cnf_nuts_dict.items():
 #   print(f'{nut}:{units}')

with_units_arr = []
for nut, unit in cnf_nuts_dict.items():
    if nut=="fat (total lipids)":
        nut = 'fat'
    elif nut == "carbohydrate, total (by difference)":
        nut = 'carbohydrate'
    elif nut=="fibre, total dietary":
        nut = 'fiber'
    elif nut == "fatty acids, polyunsaturated, 18:2undifferentiated, linoleic, octadecadienoic":
        nut = 'linoleic acid'
    elif nut == 'fatty acids, polyunsaturated, 18:3undifferentiated, linolenic, octadecatrienoic':
        nut = 'alpha-linolenic acid'
    elif nut == "vitamin d (d2 + d3)":
        nut = 'vitamin d'
    elif nut == "niacin (nicotinic acid) preformed":
        nut = 'niacin'
    elif nut == "dietary folate equivalents":
        nut = 'folate'
    elif nut == 'vitamin b12, added':
        nut = 'vitamin b12'
    elif nut == 'choline, total':
        nut = 'choline'
    elif nut == 'alpha-tocopherol':
        nut = 'vitamin e'
    elif nut == 'retinol':
        nut = 'vitamin a'
    elif nut == 'vitamin b-6':
        nut = 'vitamin b6'
    elif nut == 'vitamin b-12':
        nut = 'vitamin b12'
    with_units_arr.append(nut)

#for k,v in cnf_nuts_dict.items():
    #print(f'{k}:{v}')
#print(with_units_arr)
#print(nuts_totals_dict['Name'], len(nuts_totals_dict['Name']))
cnf_nuts_dict = dict(zip(with_units_arr, cnf_units_arr))

# %%
for nut, units in cnf_nuts_dict.items():
    print(f'{nut}:{units}')
# Out:
# protein:g/d
# fat:g/d
# carbohydrate:g/d
# ash, total:g/d
# energy (kilocalories):kCal/d
# starch:g/d
# sucrose:g/d
# glucose:g/d
# fructose:g/d
# lactose:g/d
# maltose:g/d
# alcohol:g/d
# oxalic acid:mg/d
# moisture:g/d
# mannitol:g/d
# sorbitol:g/d
# caffeine:mg/d
# theobromine:mg/d
# energy (kilojoules):kJ/d
# sugars, total:g/d
# galactose:g/d
# fiber:g/d
# calcium:mg/d
# iron:mg/d
# magnesium:mg/d
# phosphorus:mg/d
# potassium:mg/d
# sodium:mg/d
# zinc:mg/d
# copper:mg/d
# manganese:mg/d
# selenium:ug/d
# vitamin a:ug/d
# retinol activity equivalents:ug/d
# beta carotene:ug/d
# alpha carotene:ug/d
# vitamin e:mg/d
# vitamin d (international units):IU/d
# vitamin d2, ergocalciferol:ug/d
# vitamin d:ug/d
# beta cryptoxanthin:ug/d
# lycopene:ug/d
# lutein and zeaxanthin:ug/d
# beta-tocopherol:mg/d
# gamma-tocopherol:mg/d
# delta-tocopherol:mg/d
# vitamin c:mg/d
# thiamin:mg/d
# riboflavin:mg/d
# niacin:mg/d
# total niacin equivalent:NE/d
# pantothenic acid:mg/d
# vitamin b6:mg/d
# biotin:ug/d
# total folacin:ug/d
# vitamin b12:ug/d
# choline:mg/d
# vitamin k:ug/d
# folic acid:ug/d
# naturally occurring folate:ug/d
# folate:ug/d
# betaine:mg/d
# tryptophan:g/d
# threonine:g/d
# isoleucine:g/d
# leucine:g/d
# lysine:g/d
# methionine:g/d
# cystine:g/d
# phenylalanine:g/d
# tyrosine:g/d
# valine:g/d
# arginine:g/d
# histidine:g/d
# alanine:g/d
# aspartic acid:g/d
# glutamic acid:g/d
# glycine:g/d
# proline:g/d
# serine:g/d
# hydroxyproline:g/d
# aspartame:mg/d
# alpha-tocopherol, added:mg/d
# cholesterol:mg/d
# fatty acids, trans, total:g/d
# fatty acids, saturated, total:g/d
# fatty acids, saturated, 4:0, butanoic:g/d
# fatty acids, saturated, 6:0, hexanoic:g/d
# fatty acids, saturated, 8:0, octanoic:g/d
# fatty acids, saturated, 10:0, decanoic:g/d
# fatty acids, saturated, 12:0, dodecanoic:g/d
# fatty acids, saturated, 14:0, tetradecanoic:g/d
# fatty acids, saturated, 16:0, hexadecanoic:g/d
# fatty acids, saturated, 18:0, octadecanoic:g/d
# fatty acids, saturated, 20:0, eicosanoic:g/d
# fatty acids, monounsaturated, 18:1undifferentiated, octadecenoic:g/d
# linoleic acid:g/d
# alpha-linolenic acid:g/d
# fatty acids, polyunsaturated, 20:4, eicosatetraenoic:g/d
# fatty acids, polyunsaturated, 22:6 n-3, docosahexaenoic (dha):g/d
# fatty acids, saturated, 22:0, docosanoic:g/d
# fatty acids, monounsaturated, 14:1, tetradecenoic:g/d
# fatty acids, monounsaturated, 16:1undifferentiated, hexadecenoic:g/d
# fatty acids, polyunsaturated, 18:4, octadecatetraenoic:g/d
# fatty acids, monounsaturated, 20:1, eicosenoic:g/d
# fatty acids, polyunsaturated, 20:5 n-3, eicosapentaenoic (epa):g/d
# fatty acids, monounsaturated, 22:1undifferentiated, docosenoic:g/d
# fatty acids, polyunsaturated, 22:5 n-3, docosapentaenoic (dpa):g/d
# total plant sterol:mg/d
# stigmasterol:mg/d
# campesterol:mg/d
# beta-sitosterol:mg/d
# fatty acids, monounsaturated, total:g/d
# fatty acids, polyunsaturated, total:g/d
# fatty acids, saturated, 15:0, pentadecanoic:g/d
# fatty acids, saturated, 17:0, heptadecanoic:g/d
# fatty acids, saturated, 24:0, tetracosanoic:g/d
# fatty acids, monounsaturated, 16:1t, hexadecenoic:g/d
# fatty acids, monounsaturated, 18:1t, octadecenoic:g/d
# fatty acids, monounsaturated, 22:1t, docosenoic:g/d
# fatty acids, polyunsaturated, 18:2i, linoleic, octadecadienoic:g/d
# fatty acids, polyunsaturated, 18:2t,t , octadecadienenoic:g/d
# fatty acids, polyunsaturated, conjugated, 18:2 cla, linoleic, octadecadienoic:g/d
# fatty acids, monounsaturated, 24:1c, tetracosenoic:g/d
# fatty acids, polyunsaturated, 20:2 c,c  eicosadienoic:g/d
# fatty acids, monounsaturated, 16:1c, hexadecenoic:g/d
# fatty acids, monounsaturated, 18:1c, octadecenoic:g/d
# fatty acids, polyunsaturated, 18:2 c,c n-6,  linoleic, octadecadienoic:g/d
# fatty acids, monounsaturated, 22:1c, docosenoic:g/d
# fatty acids, polyunsaturated, 18:3 c,c,c n-6, g-linolenic, octadecatrienoic:g/d
# fatty acids, monounsaturated, 17:1, heptadecenoic:g/d
# fatty acids, polyunsaturated, 20:3, eicosatrienoic:g/d
# fatty acids, total trans-monoenoic:g/d
# fatty acids, total trans-polyenoic:g/d
# fatty acids, saturated, 13:0 tridecanoic:g/d
# fatty acids, monounsaturated, 15:1, pentadecenoic:g/d
# total monosaccarides:g/d
# total disaccharides:g/d
# fatty acids, polyunsaturated, 18:3 c,c,c n-3  linolenic, octadecatrienoic:g/d
# fatty acids, polyunsaturated, 20:3 n-3 eicosatrienoic:g/d
# fatty acids, polyunsaturated, 20:3 n-6, eicosatrienoic:g/d
# fatty acids, polyunsaturated, 20:4 n-6, arachidonic:g/d
# fatty acids, polyunsaturated, 18:3i, linolenic, octadecatrienoic:g/d
# fatty acids, polyunsaturated, 21:5:g/d
# fatty acids, polyunsaturated, 22:4 n-6, docosatetraenoic:g/d
# fatty acids, monounsaturated,  24:1undifferentiated, tetracosenoic:g/d
# fatty acids, monounsaturated, 12:1, lauroleic:g/d
# fatty acids, polyunsaturated, 22:3,:g/d
# fatty acids, polyunsaturated, 22:2, docosadienoic:g/d
# fatty acids, polyunsaturated, total omega  n-3:g/d
# fatty acids, polyunsaturated, total omega   n-6:g/d

# %%
#rename to cnf_arr
#cnf_arr = with_units_arr

# %% [markdown]
# # Waypoint: Start here to get rdi tables from MySQL

# %%
#rdi df_dict, #read from sql since csv's have alpha symbol
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String
import pymysql
rdi_engine = create_engine("mysql+pymysql://root:tennis33@localhost/rdi_db?charset=utf8mb4")#, echo=True)

print(rdi_engine.table_names())
# Out:
# ['elements_rdi', 'elements_upper_rdi', 'females_calories', 'macronutrients_dist_range', 'macronutrients_rdi', 'males_calories', 'vitamins_rdi', 'vitamins_upper_rdi']

# %%
import pandas as pd
df_dict = {}
for name in rdi_engine.table_names():
    #if name != "macronutrients_dist_range" and name !=\
    #"elements_upper_rdi" and name != "vitamins_upper_rdi":
    sql = "SELECT * from " + name
    df = pd.read_sql_query(sql, rdi_engine)
    df_dict[name] = df
    print(f'{name}, {df.dtypes}\n{df}')
# Out:
# elements_rdi, Life-Stage Group     object
# Calcium (mg/d)       object
# Chromium (ug/d)      object
# Copper (ug/d)        object
# Fluoride (mg/d)      object
# Iodine (ug/d)        object
# Iron (mg/d)          object
# Magnesium (mg/d)     object
# Manganese (mg/d)     object
# Molybdenum (ug/d)    object
# Phosphorus (mg/d)    object
# Selenium (ug/d)      object
# Zinc (mg/d)          object
# Potassium (mg/d)     object
# Sodium (mg/d)        object
# Chloride (g/d)       object
# dtype: object
#    Life-Stage Group Calcium (mg/d) Chromium (ug/d) Copper (ug/d)  \
# 0           Infants           None            None          None
# 1            < 6 mo            200             0.2           200
# 2           < 12 mo            260             5.5           220
# 3          Children           None            None          None
# 4          1 to 3 y            700              11           340
# 5          4 to 8 y           1000              15           440
# 6             Males           None            None          None
# 7         9 to 13 y           1300              25           700
# 8        14 to 18 y           1300              35           890
# 9        19 to 30 y           1000              35           900
# 10       31 to 50 y           1000              35           900
# 11         51 to 70           1000              30           900
# 12           > 70 y           1200              30           900
# 13          Females           None            None          None
# 14        9 to 13 y           1300              21           700
# 15       14 to 18 y           1300              24           890
# 16       19 to 30 y           1000              25           900
# 17       31 to 50 y           1000              25           900
# 18       51 to 70 y           1200              20           900
# 19           > 70 y           1200              20           900
# 20        Pregnancy           None            None          None
# 21       14 to 18 y           1300              29          1000
# 22       19 to 30 y           1000              30          1000
# 23       31 to 50 y           1000              30          1000
# 24         Lacation           None            None          None
# 25       14 to 18 y           1300              44          1300
# 26       19 to 30 y           1000              45          1300
# 27       31 to 50 y           1000              45          1300
#
#    Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0             None          None        None             None
# 1             0.01           110        0.27               30
# 2              0.5           130          11               75
# 3             None          None        None             None
# 4              0.7            90           7               80
# 5                1            90          10              130
# 6             None          None        None             None
# 7                2           120           8              240
# 8                3           150          11              410
# 9                4           150           8              400
# 10               4           150           8              420
# 11               4           150           8              420
# 12               4           150           8              420
# 13            None          None        None             None
# 14               2           120           8              240
# 15               3           150          15              360
# 16               3           150          18              310
# 17               3           150          18              320
# 18               3           150           8              320
# 19               3           150           8              320
# 20            None          None        None             None
# 21               3           220          27              400
# 22               3           220          27              350
# 23               3           220          27              360
# 24            None          None        None             None
# 25               3           290          10              360
# 26               3           290           9              310
# 27               3           290           9              320
#
#    Manganese (mg/d) Molybdenum (ug/d) Phosphorus (mg/d) Selenium (ug/d)  \
# 0              None              None              None            None
# 1             0.003                 2               100              15
# 2               0.6                 3               275              20
# 3              None              None              None            None
# 4               1.2                17               460              20
# 5               1.5                22               500              30
# 6              None              None              None            None
# 7               1.9                34              1250              40
# 8               2.2                43              1250              55
# 9               2.3                45               700              55
# 10              2.3                45               700              55
# 11              2.3                45               700              55
# 12              2.3                45               700              55
# 13             None              None              None            None
# 14              1.6                34              1250              40
# 15              1.6                43              1250              55
# 16              1.8                45               700              55
# 17              1.8                45               700              55
# 18              1.8                45               700              55
# 19              1.8                45               700              55
# 20             None              None              None            None
# 21              2.0                50              1250              60
# 22              2.0                50               700              60
# 23              2.0                50               700              60
# 24             None              None              None            None
# 25              2.6                50              1250              70
# 26              2.6                50               700              70
# 27              2.6                50               700              70
#
#    Zinc (mg/d) Potassium (mg/d) Sodium (mg/d) Chloride (g/d)
# 0         None             None          None           None
# 1            2              400           110           0.18
# 2            3              860           370           0.57
# 3         None             None          None           None
# 4            3             2000           800            1.5
# 5            5             2300          1000            1.9
# 6         None             None          None           None
# 7            8             2500          1200            2.3
# 8           11             3000          1500            2.3
# 9           11             3400          1500            2.3
# 10          11             3400          1500            2.3
# 11          11             3400          1500            2.0
# 12          11             3400          1500            1.8
# 13        None             None          None           None
# 14           8             2300          1200            2.3
# 15           9             2300          1500            2.3
# 16           8             2600          1500            2.3
# 17           8             2600          1500            2.3
# 18           8             2600          1500            2.0
# 19           8             2600          1500            1.8
# 20        None             None          None           None
# 21          12             2600          1500            2.3
# 22          11             2900          1500            2.3
# 23          11             2900          1500            2.3
# 24        None             None          None           None
# 25          13             2500          1500            2.3
# 26          12             2800          1500            2.3
# 27          12             2800          1500            2.3
# elements_upper_rdi, Life-Stage Group     object
# Arsenic              object
# Boron (mg/d)         object
# Calcium (mg/d)       object
# Chromium             object
# Copper (ug/d)        object
# Fluoride (mg/d)      object
# Iodine (ug/d)        object
# Iron (mg/d)          object
# Magnesium (mg/d)     object
# Manganese (mg/d)     object
# Molybdenum (ug/d)    object
# Nickel (mg/d)        object
# Phosphorus (g/d)     object
# Potassium            object
# Selenium (ug/d)      object
# Silicon              object
# Sulfate              object
# Vanadium (mg/d)      object
# Zinc (mg/d)          object
# Sodium               object
# Chloride (g/d)       object
# dtype: object
#    Life-Stage Group Arsenic Boron (mg/d) Calcium (mg/d) Chromium  \
# 0           Infants    None         None           None     None
# 1            < 6 mo      ND           ND           1000       ND
# 2           < 12 mo      ND           ND           1500       ND
# 3          Children    None         None           None     None
# 4          1 to 3 y      ND            3           2500       ND
# 5          4 to 8 y      ND            6           2500       ND
# 6             Males    None         None           None     None
# 7         9 to 13 y      ND           11           3000       ND
# 8        14 to 18 y      ND           17          3 000       ND
# 9        19 to 30 y      ND           20           2500       ND
# 10       31 to 50 y      ND           20           2500       ND
# 11         51 to 70      ND           20           2000       ND
# 12           > 70 y      ND           20           2000       ND
# 13          Females    None         None           None     None
# 14        9 to 13 y      ND           11           3000       ND
# 15       14 to 18 y      ND           17           3000       ND
# 16       19 to 30 y      ND           20           2500       ND
# 17       31 to 50 y      ND           20           2500       ND
# 18       51 to 70 y      ND           20           2000       ND
# 19           > 70 y      ND           20           2000       ND
# 20        Pregnancy    None         None           None     None
# 21       14 to 18 y      ND           17           3000       ND
# 22       19 to 30 y      ND           20           2500       ND
# 23       31 to 50 y      ND           20           2500       ND
# 24         Lacation    None         None           None     None
# 25       14 to 18 y      ND           17           3000       ND
# 26       19 to 30 y      ND           20           2500       ND
# 27       31 to 50 y      ND           20           2500       ND
#
#    Copper (ug/d) Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0           None            None          None        None             None
# 1             ND             0.7            ND          40               ND
# 2             ND             0.9            ND          40               ND
# 3           None            None          None        None             None
# 4           1000             1.3           200          40               65
# 5           3000             2.2           300          40              110
# 6           None            None          None        None             None
# 7           5000              10           600          40              350
# 8          8 000              10           900          45              350
# 9          10000              10          1100          45              350
# 10         10000              10          1100          45              350
# 11         10000              10          1100          45              350
# 12         10000              10          1100          45              350
# 13          None            None          None        None             None
# 14          5000              10           600          40              350
# 15          8000              10           900          45              350
# 16         10000              10          1100          45              350
# 17         10000              10          1100          45              350
# 18         10000              10          1100          45              350
# 19         10000              10          1100          45              350
# 20          None            None          None        None             None
# 21          8000              10           900          45              350
# 22         10000              10          1100          45              350
# 23         10000              10          1100          45              350
# 24          None            None          None        None             None
# 25          8000              10           900          45              350
# 26         10000              10          1100          45              350
# 27         10000              10          1100          45              350
#
#     ... Nickel (mg/d) Phosphorus (g/d) Potassium Selenium (ug/d) Silicon  \
# 0   ...          None             None      None            None    None
# 1   ...            ND               ND        ND              45      ND
# 2   ...            ND               ND        ND              60      ND
# 3   ...          None             None      None            None    None
# 4   ...           0.2                3        ND              90      ND
# 5   ...           0.3                3        ND             150      ND
# 6   ...          None             None      None            None    None
# 7   ...           0.6                4        ND             280      ND
# 8   ...           1.0                4        ND             400      ND
# 9   ...           1.0                4        ND             400      ND
# 10  ...           1.0                4        ND             400      ND
# 11  ...           1.0                4        ND             400      ND
# 12  ...           1.0                3        ND             400      ND
# 13  ...          None             None      None            None    None
# 14  ...           0.6                4        ND             280      ND
# 15  ...           1.0                4        ND             400      ND
# 16  ...           1.0                4        ND             400      ND
# 17  ...           1.0                4        ND             400      ND
# 18  ...           1.0                4        ND             400      ND
# 19  ...           1.0                3        ND             400      ND
# 20  ...          None             None      None            None    None
# 21  ...           1.0              3.5        ND             400      ND
# 22  ...           1.0              3.5        ND             400      ND
# 23  ...           1.0              3.5        ND             400      ND
# 24  ...          None             None      None            None    None
# 25  ...           1.0                4        ND             400      ND
# 26  ...           1.0                4        ND             400      ND
# 27  ...           1.0                4        ND             400      ND
#
#    Sulfate Vanadium (mg/d) Zinc (mg/d) Sodium Chloride (g/d)
# 0     None            None        None   None           None
# 1       ND              ND           4     ND             ND
# 2       ND              ND           5     ND             ND
# 3     None            None        None   None           None
# 4       ND              ND           7     ND            2.3
# 5       ND              ND          12     ND            2.9
# 6     None            None        None   None           None
# 7       ND              ND          23     ND            3.4
# 8       ND              ND          34     ND            3.6
# 9       ND             1.8          40     ND            3.6
# 10      ND             1.8          40     ND            3.6
# 11      ND             1.8          40     ND            3.6
# 12      ND             1.8          40     ND            3.6
# 13    None            None        None   None           None
# 14      ND              ND          23     ND            3.4
# 15      ND              ND          34     ND            3.6
# 16      ND             1.8          40     ND            3.6
# 17      ND             1.8          40     ND            3.6
# 18      ND             1.8          40     ND            3.6
# 19      ND             1.8          40     ND            3.6
# 20    None            None        None   None           None
# 21      ND              ND          34     ND            3.6
# 22      ND              ND          40     ND            3.6
# 23      ND              ND          40     ND            3.6
# 24    None            None        None   None           None
# 25      ND              ND          34     ND            3.6
# 26      ND              ND          40     ND            3.6
# 27      ND              ND          40     ND            3.6
#
# [28 rows x 22 columns]
# females_calories, age                  object
# sedentary            object
# moderately_active    object
# active               object
# dtype: object
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,200  1,400
# 2           4     1,200             1,400  1,400
# 3           5     1,200             1,400  1,600
# 4           6     1,200             1,400  1,600
# 5           7     1,200             1,600  1,800
# 6           8     1,400             1,600  1,800
# 7           9     1,400             1,600  1,800
# 8          10     1,400             1,800  2,000
# 9          11     1,600             1,800  2,000
# 10         12     1,600             2,000  2,200
# 11         13     1,600             2,000  2,200
# 12         14     1,800             2,000  2,400
# 13         15     1,800             2,000  2,400
# 14         16     1,800             2,000  2,400
# 15         17     1,800             2,000  2,400
# 16         18     1,800             2,000  2,400
# 17      19-20     2,000             2,200  2,400
# 18      21-25     2,000             2,200  2,400
# 19      26-30     1,800             2,000  2,400
# 20      31-35     1,800             2,000  2,200
# 21      36-40     1,800             2,000  2,200
# 22      41-45     1,800             2,000  2,200
# 23      46-50     1,800             2,000  2,200
# 24      51-55     1,600             1,800  2,200
# 25      56-60     1,600             1,800  2,200
# 26      61-65     1,600             1,800  2,000
# 27      66-70     1,600             1,800  2,000
# 28      71-75     1,600             1,800  2,000
# 29  76 and up     1,600             1,800  2,000
# macronutrients_dist_range, Life-Stage Group         object
# Fat                       int64
# Linoleic Acid             int64
# alpha-Linolenic Acid    float64
# Carbohydrate              int64
# Protein                   int64
# dtype: object
#   Life-Stage Group  Fat  Linoleic Acid  alpha-Linolenic Acid  Carbohydrate  \
# 0     child <= 3 y   30              5                   0.6            45
# 1    child <= 18 y   25              5                   0.6            45
# 2           adults   20              5                   0.6            45
#
#    Protein
# 0        5
# 1       10
# 2       10
# macronutrients_rdi, Life-Stage Group               object
# Total Water (L/d)             float64
# Carbohydrates (g/d)           float64
# Total Fiber (g/d)              object
# Fat (g/d)                      object
# Linoleic Acid (g/d)           float64
# alpha-Linolenic Acid (g/d)    float64
# Protein (g/d)                 float64
# dtype: object
#    Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d) Total Fiber (g/d)  \
# 0           Infants                NaN                  NaN              None
# 1            < 6 mo                0.7                 60.0                ND
# 2           < 12 mo                0.8                 95.0                ND
# 3          Children                NaN                  NaN              None
# 4          1 to 3 y                1.3                130.0                19
# 5          4 to 8 y                1.7                130.0                25
# 6             Males                NaN                  NaN              None
# 7         9 to 13 y                2.4                130.0                31
# 8        14 to 18 y                3.3                130.0                38
# 9        19 to 30 y                3.7                130.0                38
# 10       31 to 50 y                3.7                130.0                38
# 11         51 to 70                3.7                130.0                30
# 12           > 70 y                3.7                130.0                30
# 13          Females                NaN                  NaN              None
# 14        9 to 13 y                2.1                130.0                26
# 15       14 to 18 y                2.3                130.0                26
# 16       19 to 30 y                2.7                130.0                25
# 17       31 to 50 y                2.7                130.0                25
# 18       51 to 70 y                2.7                130.0                21
# 19           > 70 y                2.7                130.0                21
# 20        Pregnancy                NaN                  NaN              None
# 21       14 to 18 y                3.0                175.0                28
# 22       19 to 30 y                3.0                175.0                28
# 23       31 to 50 y                3.0                175.0                28
# 24         Lacation                NaN                  NaN              None
# 25       14 to 18 y                3.8                210.0                29
# 26       19 to 30 y                3.8                210.0                29
# 27       31 to 50 y                3.8                210.0                29
#
#    Fat (g/d)  Linoleic Acid (g/d)  alpha-Linolenic Acid (g/d)  Protein (g/d)
# 0       None                  NaN                         NaN            NaN
# 1         31                  4.4                         0.5            9.1
# 2         30                  4.6                         0.5           11.0
# 3       None                  NaN                         NaN            NaN
# 4         ND                  7.0                         0.7           13.0
# 5         ND                 10.0                         0.9           19.0
# 6       None                  NaN                         NaN            NaN
# 7         ND                 12.0                         1.2           34.0
# 8         ND                 16.0                         1.6           52.0
# 9         ND                 17.0                         1.6           56.0
# 10        ND                 17.0                         1.6           56.0
# 11        ND                 14.0                         1.6           56.0
# 12        ND                 14.0                         1.6           56.0
# 13      None                  NaN                         NaN            NaN
# 14        ND                 10.0                         1.0           34.0
# 15        ND                 11.0                         1.1           46.0
# 16        ND                 12.0                         1.1           46.0
# 17        ND                 12.0                         1.1           46.0
# 18        ND                 11.0                         1.1           46.0
# 19        ND                 11.0                         1.1           46.0
# 20      None                  NaN                         NaN            NaN
# 21        ND                 13.0                         1.4           71.0
# 22        ND                 13.0                         1.4           71.0
# 23        ND                 13.0                         1.4           71.0
# 24      None                  NaN                         NaN            NaN
# 25        ND                 13.0                         1.3           71.0
# 26        ND                 13.0                         1.3           71.0
# 27        ND                 13.0                         1.3           71.0
# males_calories, age                  object
# sedentary            object
# moderately_active    object
# active               object
# dtype: object
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,400  1,400
# 2           4     1,200             1,400  1,600
# 3           5     1,200             1,400  1,600
# 4           6     1,400             1,600  1,800
# 5           7     1,400             1,600  1,800
# 6           8     1,400             1,600  2,000
# 7           9     1,600             1,800  2,000
# 8          10     1,600             1,800  2,200
# 9          11     1,800             2,000  2,200
# 10         12     1,800             2,200  2,400
# 11         13     2,000             2,200  2,600
# 12         14     2,000             2,400  2,800
# 13         15     2,200             2,600  3,000
# 14         16     2,400             2,800  3,200
# 15         17     2,400             2,800  3,200
# 16         18     2,400             2,800  3,200
# 17      19-20     2,600             2,800  3,000
# 18      21-25     2,400             2,800  3,000
# 19      26-30     2,400             2,600  3,000
# 20      31-35     2,400             2,600  3,000
# 21      36-40     2,400             2,600  2,800
# 22      41-45     2,200             2,600  2,800
# 23      46-50     2,200             2,400  2,800
# 24      51-55     2,200             2,400  2,800
# 25      56-60     2,200             2,400  2,600
# 26      61-65     2,000             2,400  2,600
# 27      66-70     2,000             2,200  2,600
# 28      71-75     2,000             2,200  2,600
# 29  76 and up     2,000             2,200  2,400
# vitamins_rdi, Life-Stage Group            object
# Vitamin A (ug/d)           float64
# Vitamin C (mg/d)           float64
# Vitamin D (ug/d)           float64
# Vitamin E (mg/d)           float64
# Vitamin K (ug/d)           float64
# Thiamin (mg/d)             float64
# Riboflavin (mg/d)          float64
# Niacin (mg/d)              float64
# Vitamin B6 (mg/d)          float64
# Folate (ug/d)              float64
# Vitamin B12 (ug/d)         float64
# Pantothenic Acid (mg/d)    float64
# Biotin (ug/d)              float64
# Choline (mg/d)             float64
# dtype: object
#    Life-Stage Group  Vitamin A (ug/d)  Vitamin C (mg/d)  Vitamin D (ug/d)  \
# 0           Infants               NaN               NaN               NaN
# 1            < 6 mo             400.0              40.0              10.0
# 2           < 12 mo             500.0              50.0              10.0
# 3          Children               NaN               NaN               NaN
# 4          1 to 3 y             300.0              15.0              15.0
# 5          4 to 8 y             400.0              25.0              15.0
# 6             Males               NaN               NaN               NaN
# 7         9 to 13 y             600.0              45.0              15.0
# 8        14 to 18 y             900.0              75.0              15.0
# 9        19 to 30 y             900.0              90.0              15.0
# 10       31 to 50 y             900.0              90.0              15.0
# 11         51 to 70             900.0              90.0              15.0
# 12           > 70 y             900.0              90.0              20.0
# 13          Females               NaN               NaN               NaN
# 14        9 to 13 y             600.0              45.0              15.0
# 15       14 to 18 y             700.0              65.0              15.0
# 16       19 to 30 y             700.0              75.0              15.0
# 17       31 to 50 y             700.0              75.0              15.0
# 18       51 to 70 y             700.0              75.0              15.0
# 19           > 70 y             700.0              75.0              20.0
# 20        Pregnancy               NaN               NaN               NaN
# 21       14 to 18 y             750.0              80.0              15.0
# 22       19 to 30 y             770.0              85.0              15.0
# 23       31 to 50 y             770.0              85.0              15.0
# 24         Lacation               NaN               NaN               NaN
# 25       14 to 18 y            1200.0             115.0              15.0
# 26       19 to 30 y            1300.0             120.0              15.0
# 27       31 to 50 y            1300.0             120.0              15.0
#
#     Vitamin E (mg/d)  Vitamin K (ug/d)  Thiamin (mg/d)  Riboflavin (mg/d)  \
# 0                NaN               NaN             NaN                NaN
# 1                4.0               2.0             0.2                0.3
# 2                5.0               2.5             0.3                0.4
# 3                NaN               NaN             NaN                NaN
# 4                6.0              30.0             0.5                0.5
# 5                7.0              55.0             0.6                0.6
# 6                NaN               NaN             NaN                NaN
# 7               11.0              60.0             0.9                0.9
# 8               15.0              75.0             1.2                1.3
# 9               15.0             120.0             1.2                1.3
# 10              15.0             120.0             1.2                1.3
# 11              15.0             120.0             1.2                1.3
# 12              15.0             120.0             1.2                1.3
# 13               NaN               NaN             NaN                NaN
# 14              11.0              60.0             0.9                0.9
# 15              15.0              75.0             1.0                1.0
# 16              15.0              90.0             1.1                1.1
# 17              15.0              90.0             1.1                1.1
# 18              15.0              90.0             1.1                1.1
# 19              15.0              90.0             1.1                1.1
# 20               NaN               NaN             NaN                NaN
# 21              15.0              75.0             1.4                1.4
# 22              15.0              90.0             1.4                1.4
# 23              15.0              90.0             1.4                1.4
# 24               NaN               NaN             NaN                NaN
# 25              19.0              75.0             1.4                1.6
# 26              19.0              90.0             1.4                1.6
# 27              19.0              90.0             1.4                1.6
#
#     Niacin (mg/d)  Vitamin B6 (mg/d)  Folate (ug/d)  Vitamin B12 (ug/d)  \
# 0             NaN                NaN            NaN                 NaN
# 1             2.0                0.1           65.0                 0.4
# 2             4.0                0.3           80.0                 0.5
# 3             NaN                NaN            NaN                 NaN
# 4             6.0                0.5          150.0                 0.9
# 5             8.0                0.6          200.0                 1.2
# 6             NaN                NaN            NaN                 NaN
# 7            12.0                1.0          300.0                 1.8
# 8            16.0                1.3          400.0                 2.4
# 9            16.0                1.3          400.0                 2.4
# 10           16.0                1.3          400.0                 2.4
# 11           16.0                1.7          400.0                 2.4
# 12           16.0                1.7          400.0                 2.4
# 13            NaN                NaN            NaN                 NaN
# 14           12.0                1.0          300.0                 1.8
# 15           14.0                1.2          400.0                 2.4
# 16           14.0                1.3          400.0                 2.4
# 17           14.0                1.3          400.0                 2.4
# 18           14.0                1.5          400.0                 2.4
# 19           14.0                1.5          400.0                 2.4
# 20            NaN                NaN            NaN                 NaN
# 21           18.0                1.9          600.0                 2.6
# 22           18.0                1.9          600.0                 2.6
# 23           18.0                1.9          600.0                 2.6
# 24            NaN                NaN            NaN                 NaN
# 25           17.0                2.0          500.0                 2.8
# 26           17.0                2.0          500.0                 2.8
# 27           17.0                2.0          500.0                 2.8
#
#     Pantothenic Acid (mg/d)  Biotin (ug/d)  Choline (mg/d)
# 0                       NaN            NaN             NaN
# 1                       1.7            5.0           125.0
# 2                       1.8            6.0           150.0
# 3                       NaN            NaN             NaN
# 4                       2.0            8.0           200.0
# 5                       3.0           12.0           250.0
# 6                       NaN            NaN             NaN
# 7                       4.0           20.0           375.0
# 8                       5.0           25.0           550.0
# 9                       5.0           30.0           550.0
# 10                      5.0           30.0           550.0
# 11                      5.0           30.0           550.0
# 12                      5.0           30.0           550.0
# 13                      NaN            NaN             NaN
# 14                      4.0           20.0           375.0
# 15                      5.0           25.0           400.0
# 16                      5.0           30.0           425.0
# 17                      5.0           30.0           425.0
# 18                      5.0           30.0           425.0
# 19                      5.0           30.0           425.0
# 20                      NaN            NaN             NaN
# 21                      6.0           30.0           450.0
# 22                      6.0           30.0           450.0
# 23                      6.0           30.0           450.0
# 24                      NaN            NaN             NaN
# 25                      7.0           35.0           550.0
# 26                      7.0           35.0           550.0
# 27                      7.0           35.0           550.0
# vitamins_upper_rdi, Life-Stage Group     object
# Arsenic              object
# Boron (mg/d)         object
# Calcium (mg/d)       object
# Chromium             object
# Copper (ug/d)        object
# Fluoride (mg/d)      object
# Iodine (ug/d)        object
# Iron (mg/d)          object
# Magnesium (mg/d)     object
# Manganese (mg/d)     object
# Molybdenum (ug/d)    object
# Nickel (mg/d)        object
# Phosphorus (g/d)     object
# Potassium            object
# Selenium (ug/d)      object
# Silicon              object
# Sulfate              object
# Vanadium (mg/d)      object
# Zinc (mg/d)          object
# Sodium               object
# Chloride (g/d)       object
# dtype: object
#    Life-Stage Group Arsenic Boron (mg/d) Calcium (mg/d) Chromium  \
# 0           Infants    None         None           None     None
# 1            < 6 mo      ND           ND           1000       ND
# 2           < 12 mo      ND           ND           1500       ND
# 3          Children    None         None           None     None
# 4          1 to 3 y      ND            3           2500       ND
# 5          4 to 8 y      ND            6           2500       ND
# 6             Males    None         None           None     None
# 7         9 to 13 y      ND           11           3000       ND
# 8        14 to 18 y      ND           17          3 000       ND
# 9        19 to 30 y      ND           20           2500       ND
# 10       31 to 50 y      ND           20           2500       ND
# 11         51 to 70      ND           20           2000       ND
# 12           > 70 y      ND           20           2000       ND
# 13          Females    None         None           None     None
# 14        9 to 13 y      ND           11           3000       ND
# 15       14 to 18 y      ND           17           3000       ND
# 16       19 to 30 y      ND           20           2500       ND
# 17       31 to 50 y      ND           20           2500       ND
# 18       51 to 70 y      ND           20           2000       ND
# 19           > 70 y      ND           20           2000       ND
# 20        Pregnancy    None         None           None     None
# 21       14 to 18 y      ND           17           3000       ND
# 22       19 to 30 y      ND           20           2500       ND
# 23       31 to 50 y      ND           20           2500       ND
# 24         Lacation    None         None           None     None
# 25       14 to 18 y      ND           17           3000       ND
# 26       19 to 30 y      ND           20           2500       ND
# 27       31 to 50 y      ND           20           2500       ND
#
#    Copper (ug/d) Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d)  \
# 0           None            None          None        None             None
# 1             ND             0.7            ND          40               ND
# 2             ND             0.9            ND          40               ND
# 3           None            None          None        None             None
# 4           1000             1.3           200          40               65
# 5           3000             2.2           300          40              110
# 6           None            None          None        None             None
# 7           5000              10           600          40              350
# 8          8 000              10           900          45              350
# 9          10000              10          1100          45              350
# 10         10000              10          1100          45              350
# 11         10000              10          1100          45              350
# 12         10000              10          1100          45              350
# 13          None            None          None        None             None
# 14          5000              10           600          40              350
# 15          8000              10           900          45              350
# 16         10000              10          1100          45              350
# 17         10000              10          1100          45              350
# 18         10000              10          1100          45              350
# 19         10000              10          1100          45              350
# 20          None            None          None        None             None
# 21          8000              10           900          45              350
# 22         10000              10          1100          45              350
# 23         10000              10          1100          45              350
# 24          None            None          None        None             None
# 25          8000              10           900          45              350
# 26         10000              10          1100          45              350
# 27         10000              10          1100          45              350
#
#     ... Nickel (mg/d) Phosphorus (g/d) Potassium Selenium (ug/d) Silicon  \
# 0   ...          None             None      None            None    None
# 1   ...            ND               ND        ND              45      ND
# 2   ...            ND               ND        ND              60      ND
# 3   ...          None             None      None            None    None
# 4   ...           0.2                3        ND              90      ND
# 5   ...           0.3                3        ND             150      ND
# 6   ...          None             None      None            None    None
# 7   ...           0.6                4        ND             280      ND
# 8   ...           1.0                4        ND             400      ND
# 9   ...           1.0                4        ND             400      ND
# 10  ...           1.0                4        ND             400      ND
# 11  ...           1.0                4        ND             400      ND
# 12  ...           1.0                3        ND             400      ND
# 13  ...          None             None      None            None    None
# 14  ...           0.6                4        ND             280      ND
# 15  ...           1.0                4        ND             400      ND
# 16  ...           1.0                4        ND             400      ND
# 17  ...           1.0                4        ND             400      ND
# 18  ...           1.0                4        ND             400      ND
# 19  ...           1.0                3        ND             400      ND
# 20  ...          None             None      None            None    None
# 21  ...           1.0              3.5        ND             400      ND
# 22  ...           1.0              3.5        ND             400      ND
# 23  ...           1.0              3.5        ND             400      ND
# 24  ...          None             None      None            None    None
# 25  ...           1.0                4        ND             400      ND
# 26  ...           1.0                4        ND             400      ND
# 27  ...           1.0                4        ND             400      ND
#
#    Sulfate Vanadium (mg/d) Zinc (mg/d) Sodium Chloride (g/d)
# 0     None            None        None   None           None
# 1       ND              ND           4     ND             ND
# 2       ND              ND           5     ND             ND
# 3     None            None        None   None           None
# 4       ND              ND           7     ND            2.3
# 5       ND              ND          12     ND            2.9
# 6     None            None        None   None           None
# 7       ND              ND          23     ND            3.4
# 8       ND              ND          34     ND            3.6
# 9       ND             1.8          40     ND            3.6
# 10      ND             1.8          40     ND            3.6
# 11      ND             1.8          40     ND            3.6
# 12      ND             1.8          40     ND            3.6
# 13    None            None        None   None           None
# 14      ND              ND          23     ND            3.4
# 15      ND              ND          34     ND            3.6
# 16      ND             1.8          40     ND            3.6
# 17      ND             1.8          40     ND            3.6
# 18      ND             1.8          40     ND            3.6
# 19      ND             1.8          40     ND            3.6
# 20    None            None        None   None           None
# 21      ND              ND          34     ND            3.6
# 22      ND              ND          40     ND            3.6
# 23      ND              ND          40     ND            3.6
# 24    None            None        None   None           None
# 25      ND              ND          34     ND            3.6
# 26      ND              ND          40     ND            3.6
# 27      ND              ND          40     ND            3.6
#
# [28 rows x 22 columns]

# %%
'''
#edit elements and elements upper tables so lifestage is not across cols, change to NaN
elems_rdi = df_dict['elements_rdi']
elems_upper = df_dict['elements_upper_rdi']

need_change_dict = {'elements_rdi':elems_rdi, 'elements_upper_rdi': elems_upper}

for name, df in need_change_dict.items():
    cols = list(df.columns)
    key_cols = cols[1:]
    for idx, row in df.iterrows():
        for col in key_cols:
            val = df.loc[idx, col]
            if val in ['Infants', 'Children', 'Males', "Females", "Pregnancy", "Lactation"]:
                df.loc[idx, col] = None

for name, df in need_change_dict.items():
    #print(f'{name}\n{df}')
    df.to_sql(name, con=rdi_engine, if_exists='replace', index=False)
            
'''

# %%
print(len(df_dict))
print(df_dict.keys())
# Out:
# 8
# dict_keys(['elements_rdi', 'elements_upper_rdi', 'females_calories', 'macronutrients_dist_range', 'macronutrients_rdi', 'males_calories', 'vitamins_rdi', 'vitamins_upper_rdi'])

# %% [markdown]
# # waypoint: mutiply cols of macro by num_days for period RDI amts

# %%
macro_rdi = df_dict['macronutrients_rdi']
macro_rdi = macro_rdi.copy()
macro_rdi = macro_rdi.astype(str)
macro_rdi.iloc[:10]
# Out:
#   Life-Stage Group Total Water (L/d) Carbohydrates (g/d) Total Fiber (g/d)  \
# 0          Infants               nan                 nan              None
# 1           < 6 mo               0.7                60.0                ND
# 2          < 12 mo               0.8                95.0                ND
# 3         Children               nan                 nan              None
# 4         1 to 3 y               1.3               130.0                19
# 5         4 to 8 y               1.7               130.0                25
# 6            Males               nan                 nan              None
# 7        9 to 13 y               2.4               130.0                31
# 8       14 to 18 y               3.3               130.0                38
# 9       19 to 30 y               3.7               130.0                38
#
#   Fat (g/d) Linoleic Acid (g/d) alpha-Linolenic Acid (g/d) Protein (g/d)
# 0      None                 nan                        nan           nan
# 1        31                 4.4                        0.5           9.1
# 2        30                 4.6                        0.5          11.0
# 3      None                 nan                        nan           nan
# 4        ND                 7.0                        0.7          13.0
# 5        ND                10.0                        0.9          19.0
# 6      None                 nan                        nan           nan
# 7        ND                12.0                        1.2          34.0
# 8        ND                16.0                        1.6          52.0
# 9        ND                17.0                        1.6          56.0

# %%
#! conda list
! pip install pandas==1.1.4
# Out:
# Collecting pandas==1.1.4
#   Downloading pandas-1.1.4-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 6.6 MB/s eta 0:00:01     |█████████████████▊              | 5.3 MB 3.1 MB/s eta 0:00:02
# Requirement already satisfied: pytz>=2017.2 in /home/nobu/anaconda3/envs/gamechangers/lib/python3.7/site-packages (from pandas==1.1.4) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/nobu/anaconda3/envs/gamechangers/lib/python3.7/site-packages (from pandas==1.1.4) (1.19.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/nobu/anaconda3/envs/gamechangers/lib/python3.7/site-packages (from pandas==1.1.4) (2.8.1)
# Requirement already satisfied: six>=1.5 in /home/nobu/anaconda3/envs/gamechangers/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas==1.1.4) (1.15.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.1.1
#     Uninstalling pandas-1.1.1:
#       Successfully uninstalled pandas-1.1.1
# Successfully installed pandas-1.1.4

# %%
macro_r = macro_rdi.copy()
macro_r = macro_r.astype(str)
print(macro_r.dtypes)

num_days = 5.
cols = list(macro_r.columns)
key_cols = cols[1:]
for idx, row in macro_r.iterrows():
    #for i in range(1, len(cols)):
    for col in key_cols:
        curr_val = macro_r.loc[idx, col]
        if curr_val == 'ND' or curr_val == 'None' or curr_val == 'nan': # delete infants (fiber is ND, for fat ND, mult cals by num days)
            continue
        else:
            curr_val = float(curr_val) * num_days
            macro_r.loc[idx, col] = curr_val

print(macro_r.iloc[:10])

'''
col_count = len(list(macro_r.columns))
    for i in range (1, col_count):
        s = pd.Series(macro_r.iloc[:,i])
        if "ND" in s.values:
            continue
        else:
            float_col = rdi_df.iloc[:, i].astype(float)
'''
# Out:
# Life-Stage Group              object
# Total Water (L/d)             object
# Carbohydrates (g/d)           object
# Total Fiber (g/d)             object
# Fat (g/d)                     object
# Linoleic Acid (g/d)           object
# alpha-Linolenic Acid (g/d)    object
# Protein (g/d)                 object
# dtype: object
#   Life-Stage Group Total Water (L/d) Carbohydrates (g/d) Total Fiber (g/d)  \
# 0          Infants               nan                 nan              None
# 1           < 6 mo               3.5                 300                ND
# 2          < 12 mo                 4                 475                ND
# 3         Children               nan                 nan              None
# 4         1 to 3 y               6.5                 650                95
# 5         4 to 8 y               8.5                 650               125
# 6            Males               nan                 nan              None
# 7        9 to 13 y                12                 650               155
# 8       14 to 18 y              16.5                 650               190
# 9       19 to 30 y              18.5                 650               190
#
#   Fat (g/d) Linoleic Acid (g/d) alpha-Linolenic Acid (g/d) Protein (g/d)
# 0      None                 nan                        nan           nan
# 1       155                  22                        2.5          45.5
# 2       150                  23                        2.5            55
# 3      None                 nan                        nan           nan
# 4        ND                  35                        3.5            65
# 5        ND                  50                        4.5            95
# 6      None                 nan                        nan           nan
# 7        ND                  60                          6           170
# 8        ND                  80                          8           260
# 9        ND                  85                          8           280
# '\ncol_count = len(list(macro_r.columns))\n    for i in range (1, col_count):\n        s = pd.Series(macro_r.iloc[:,i])\n        if "ND" in s.values:\n            continue\n        else:\n            float_col = rdi_df.iloc[:, i].astype(float)\n'

# %% [markdown]
# # Practice indexing into rdi_df's

# %%
rdi_elems_df = df_dict['elements_rdi']
rdi_vits_df = df_dict['vitamins_rdi']
rdi_macros_df = df_dict['macronutrients_rdi']

print(rdi_macros_df)
print(len(rdi_macros_df.index))
# Out:
#    Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d)  \
# 0           Infants                NaN                  NaN
# 1            < 6 mo                0.7                 60.0
# 2           < 12 mo                0.8                 95.0
# 3          Children                NaN                  NaN
# 4          1 to 3 y                1.3                130.0
# 5          4 to 8 y                1.7                130.0
# 6             Males                NaN                  NaN
# 7         9 to 13 y                2.4                130.0
# 8        14 to 18 y                3.3                130.0
# 9        19 to 30 y                3.7                130.0
# 10       31 to 50 y                3.7                130.0
# 11         51 to 70                3.7                130.0
# 12           > 70 y                3.7                130.0
# 13          Females                NaN                  NaN
# 14        9 to 13 y                2.1                130.0
# 15       14 to 18 y                2.3                130.0
# 16       19 to 30 y                2.7                130.0
# 17       31 to 50 y                2.7                130.0
# 18       51 to 70 y                2.7                130.0
# 19           > 70 y                2.7                130.0
# 20        Pregnancy                NaN                  NaN
# 21       14 to 18 y                3.0                175.0
# 22       19 to 30 y                3.0                175.0
# 23       31 to 50 y                3.0                175.0
# 24         Lacation                NaN                  NaN
# 25       14 to 18 y                3.8                210.0
# 26       19 to 30 y                3.8                210.0
# 27       31 to 50 y                3.8                210.0
#
#     Total Fiber (g/d)  Fat (g/d)  Linoleic Acid (g/d)  \
# 0                 NaN        NaN                  NaN
# 1                 NaN       31.0                  4.4
# 2                 NaN       30.0                  4.6
# 3                 NaN        NaN                  NaN
# 4                19.0        NaN                  7.0
# 5                25.0        NaN                 10.0
# 6                 NaN        NaN                  NaN
# 7                31.0        NaN                 12.0
# 8                38.0        NaN                 16.0
# 9                38.0        NaN                 17.0
# 10               38.0        NaN                 17.0
# 11               30.0        NaN                 14.0
# 12               30.0        NaN                 14.0
# 13                NaN        NaN                  NaN
# 14               26.0        NaN                 10.0
# 15               26.0        NaN                 11.0
# 16               25.0        NaN                 12.0
# 17               25.0        NaN                 12.0
# 18               21.0        NaN                 11.0
# 19               21.0        NaN                 11.0
# 20                NaN        NaN                  NaN
# 21               28.0        NaN                 13.0
# 22               28.0        NaN                 13.0
# 23               28.0        NaN                 13.0
# 24                NaN        NaN                  NaN
# 25               29.0        NaN                 13.0
# 26               29.0        NaN                 13.0
# 27               29.0        NaN                 13.0
#
#     alpha-Linolenic Acid (g/d)  Protein (g/d)
# 0                          NaN            NaN
# 1                          0.5            9.1
# 2                          0.5           11.0
# 3                          NaN            NaN
# 4                          0.7           13.0
# 5                          0.9           19.0
# 6                          NaN            NaN
# 7                          1.2           34.0
# 8                          1.6           52.0
# 9                          1.6           56.0
# 10                         1.6           56.0
# 11                         1.6           56.0
# 12                         1.6           56.0
# 13                         NaN            NaN
# 14                         1.0           34.0
# 15                         1.1           46.0
# 16                         1.1           46.0
# 17                         1.1           46.0
# 18                         1.1           46.0
# 19                         1.1           46.0
# 20                         NaN            NaN
# 21                         1.4           71.0
# 22                         1.4           71.0
# 23                         1.4           71.0
# 24                         NaN            NaN
# 25                         1.3           71.0
# 26                         1.3           71.0
# 27                         1.3           71.0
# 28

# %%
# return all of 4 of them
rdi_macros_df[rdi_macros_df['Life-Stage Group']=='31 to 50 y']
#rdi_macros_df.where(rdi_macros_df['Life-Stage Group']>'Males')
infants_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Infants'][0]
child_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Children'][0]
male_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Males'][0]
fem_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Females'][0]
preg_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Pregnancy'][0]
lact_idx = rdi_macros_df.index[rdi_macros_df['Life-Stage Group']=='Lacation'][0]
print(infants_idx, child_idx, male_idx, fem_idx, preg_idx, lact_idx)

#only lact_idx is [lact_idx:]
lifestage_idxs = [infants_idx, 
                  child_idx, 
                  male_idx, 
                  fem_idx, 
                  preg_idx, 
                  lact_idx]

#dial into > male and < fem
user_type = 'male'
age_group = '31 to 50 y'
nut = 'protein'

portion = rdi_macros_df.iloc[male_idx:fem_idx, :]
print(portion)

row = portion[portion['Life-Stage Group']==age_group]
print(row)

cols = row.columns
for col in cols:
    if nut in str(col):
        target_col = col
        break
print(col)

val = row[col].item()
print(val)

cp_portion = pd.DataFrame(columns=cols)
cp_portion.loc[0,col] = 100
print(cp_portion)
# Out:
# 0 3 6 13 20 24
#    Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d)  \
# 6             Males                NaN                  NaN
# 7         9 to 13 y                2.4                130.0
# 8        14 to 18 y                3.3                130.0
# 9        19 to 30 y                3.7                130.0
# 10       31 to 50 y                3.7                130.0
# 11         51 to 70                3.7                130.0
# 12           > 70 y                3.7                130.0
#
#     Total Fiber (g/d)  Fat (g/d)  Linoleic Acid (g/d)  \
# 6                 NaN        NaN                  NaN
# 7                31.0        NaN                 12.0
# 8                38.0        NaN                 16.0
# 9                38.0        NaN                 17.0
# 10               38.0        NaN                 17.0
# 11               30.0        NaN                 14.0
# 12               30.0        NaN                 14.0
#
#     alpha-Linolenic Acid (g/d)  Protein (g/d)
# 6                          NaN            NaN
# 7                          1.2           34.0
# 8                          1.6           52.0
# 9                          1.6           56.0
# 10                         1.6           56.0
# 11                         1.6           56.0
# 12                         1.6           56.0
#    Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d)  \
# 10       31 to 50 y                3.7                130.0
#
#     Total Fiber (g/d)  Fat (g/d)  Linoleic Acid (g/d)  \
# 10               38.0        NaN                 17.0
#
#     alpha-Linolenic Acid (g/d)  Protein (g/d)
# 10                         1.6           56.0
# Protein (g/d)
# 56.0
#   Life-Stage Group Total Water (L/d) Carbohydrates (g/d) Total Fiber (g/d)  \
# 0              NaN               NaN                 NaN               NaN
#
#   Fat (g/d) Linoleic Acid (g/d) alpha-Linolenic Acid (g/d) Protein (g/d)
# 0       NaN                 NaN                        NaN           100

# %% [markdown]
# # waypoint, get cols from rdi elem, vits, macros and strip units

# %%
# function to take out units
def strip_units(nuts_arr):
    nuts_units_dict = {}
    for nut in nuts_arr:
        # take out units
        if '(g/d)' in nut:
            curr_units = 'g/d'
            new_nut = nut.replace('(g/d)', '').strip()
            nuts_units_dict[new_nut] = curr_units
        elif '(mg/d)' in nut:
            curr_units = 'mg/d'
            new_nut = nut.replace('(mg/d)', '').strip()
            nuts_units_dict[new_nut] = curr_units
        elif '(ug/d)' in nut:
            curr_units = 'ug/d'
            new_nut = nut.replace('(ug/d)', '').strip()
            nuts_units_dict[new_nut] = curr_units
        elif '(l/d)' in nut:
            curr_units = 'l/d'
            new_nut = nut.replace('(l/d)', '').strip()
            nuts_units_dict[new_nut] = curr_units
        else: # carotenoid -> alpha-carotene, beta-carotene?
            new_nut = nut
            nuts_units_dict[new_nut] = ''
    
    return nuts_units_dict

# %%
# get lists of rdi_elements, rdi_vitamins, rdi_macros
rdi_elements = []
rdi_vitamins = []
rdi_macros = []

elements_df = df_dict['elements_rdi']
vitamins_df = df_dict['vitamins_rdi']
macros_df = df_dict['macronutrients_rdi']

print(f'{elements_df.head()}\n{vitamins_df.head()}\n{macros_df.head()}' )
# Out:
#   Life-Stage Group Calcium (mg/d) Chromium (ug/d) Copper (ug/d)  \
# 0          Infants           None            None          None
# 1           < 6 mo            200             0.2           200
# 2          < 12 mo            260             5.5           220
# 3         Children           None            None          None
# 4         1 to 3 y            700              11           340
#
#   Fluoride (mg/d) Iodine (ug/d) Iron (mg/d) Magnesium (mg/d) Manganese (mg/d)  \
# 0            None          None        None             None             None
# 1            0.01           110        0.27               30            0.003
# 2             0.5           130          11               75              0.6
# 3            None          None        None             None             None
# 4             0.7            90           7               80              1.2
#
#   Molybdenum (ug/d) Phosphorus (mg/d) Selenium (ug/d) Zinc (mg/d)  \
# 0              None              None            None        None
# 1                 2               100              15           2
# 2                 3               275              20           3
# 3              None              None            None        None
# 4                17               460              20           3
#
#   Potassium (mg/d) Sodium (mg/d) Chloride (g/d)
# 0             None          None           None
# 1              400           110           0.18
# 2              860           370           0.57
# 3             None          None           None
# 4             2000           800            1.5
#   Life-Stage Group  Vitamin A (ug/d)  Vitamin C (mg/d)  Vitamin D (ug/d)  \
# 0          Infants               NaN               NaN               NaN
# 1           < 6 mo             400.0              40.0              10.0
# 2          < 12 mo             500.0              50.0              10.0
# 3         Children               NaN               NaN               NaN
# 4         1 to 3 y             300.0              15.0              15.0
#
#    Vitamin E (mg/d)  Vitamin K (ug/d)  Thiamin (mg/d)  Riboflavin (mg/d)  \
# 0               NaN               NaN             NaN                NaN
# 1               4.0               2.0             0.2                0.3
# 2               5.0               2.5             0.3                0.4
# 3               NaN               NaN             NaN                NaN
# 4               6.0              30.0             0.5                0.5
#
#    Niacin (mg/d)  Vitamin B6 (mg/d)  Folate (ug/d)  Vitamin B12 (ug/d)  \
# 0            NaN                NaN            NaN                 NaN
# 1            2.0                0.1           65.0                 0.4
# 2            4.0                0.3           80.0                 0.5
# 3            NaN                NaN            NaN                 NaN
# 4            6.0                0.5          150.0                 0.9
#
#    Pantothenic Acid (mg/d)  Biotin (ug/d)  Choline (mg/d)
# 0                      NaN            NaN             NaN
# 1                      1.7            5.0           125.0
# 2                      1.8            6.0           150.0
# 3                      NaN            NaN             NaN
# 4                      2.0            8.0           200.0
#   Life-Stage Group  Total Water (L/d)  Carbohydrates (g/d) Total Fiber (g/d)  \
# 0          Infants                NaN                  NaN              None
# 1           < 6 mo                0.7                 60.0                ND
# 2          < 12 mo                0.8                 95.0                ND
# 3         Children                NaN                  NaN              None
# 4         1 to 3 y                1.3                130.0                19
#
#   Fat (g/d)  Linoleic Acid (g/d)  alpha-Linolenic Acid (g/d)  Protein (g/d)
# 0      None                  NaN                         NaN            NaN
# 1        31                  4.4                         0.5            9.1
# 2        30                  4.6                         0.5           11.0
# 3      None                  NaN                         NaN            NaN
# 4        ND                  7.0                         0.7           13.0

# %%
rdi_elements = [x.lower() for x in elements_df.columns.tolist() if x != "Life-Stage Group"]
rdi_elems_dict = strip_units(rdi_elements)
print(len(rdi_elements))
print(len(rdi_elems_dict))
for nut, units in rdi_elems_dict.items():
    print(f'{nut}:{units}')
    
rdi_vitamins = [x.lower() for x in vitamins_df.columns.tolist() if x != "Life-Stage Group"]
rdi_vits_dict = strip_units(rdi_vitamins)
print(len(rdi_vitamins))
print(len(rdi_vits_dict))
for nut, units in rdi_vits_dict.items():
    print(f'{nut}:{units}')

rdi_macros = [x.lower() for x in macros_df.columns.tolist() if x != "Life-Stage Group"]
rdi_macros_dict = strip_units(rdi_macros)
print(len(rdi_macros))
print(len(rdi_macros_dict))
for nut, units in rdi_macros_dict.items():
    print(f'{nut}:{units}')


#print(f'{rdi_elements}\n{rdi_vitamins}\n{rdi_macros}\n')
# Out:
# 15
# 15
# calcium:mg/d
# chromium:ug/d
# copper:ug/d
# fluoride:mg/d
# iodine:ug/d
# iron:mg/d
# magnesium:mg/d
# manganese:mg/d
# molybdenum:ug/d
# phosphorus:mg/d
# selenium:ug/d
# zinc:mg/d
# potassium:mg/d
# sodium:mg/d
# chloride:g/d
# 14
# 14
# vitamin a:ug/d
# vitamin c:mg/d
# vitamin d:ug/d
# vitamin e:mg/d
# vitamin k:ug/d
# thiamin:mg/d
# riboflavin:mg/d
# niacin:mg/d
# vitamin b6:mg/d
# folate:ug/d
# vitamin b12:ug/d
# pantothenic acid:mg/d
# biotin:ug/d
# choline:mg/d
# 7
# 7
# total water:l/d
# carbohydrates:g/d
# total fiber:g/d
# fat:g/d
# linoleic acid:g/d
# alpha-linolenic acid:g/d
# protein:g/d

# %%
for name, units in cnf_nuts_dict.items():
    print(f'{name}:{units}')
# Out:
# protein:g/d
# fat:g/d
# carbohydrate:g/d
# ash, total:g/d
# energy (kilocalories):kCal/d
# starch:g/d
# sucrose:g/d
# glucose:g/d
# fructose:g/d
# lactose:g/d
# maltose:g/d
# alcohol:g/d
# oxalic acid:mg/d
# moisture:g/d
# mannitol:g/d
# sorbitol:g/d
# caffeine:mg/d
# theobromine:mg/d
# energy (kilojoules):kJ/d
# sugars, total:g/d
# galactose:g/d
# fiber:g/d
# calcium:mg/d
# iron:mg/d
# magnesium:mg/d
# phosphorus:mg/d
# potassium:mg/d
# sodium:mg/d
# zinc:mg/d
# copper:mg/d
# manganese:mg/d
# selenium:ug/d
# retinol:ug/d
# retinol activity equivalents:ug/d
# beta carotene:ug/d
# alpha carotene:ug/d
# alpha-tocopherol:mg/d
# vitamin d (international units):IU/d
# vitamin d2, ergocalciferol:ug/d
# vitamin d (d2 + d3):ug/d
# beta cryptoxanthin:ug/d
# lycopene:ug/d
# lutein and zeaxanthin:ug/d
# beta-tocopherol:mg/d
# gamma-tocopherol:mg/d
# delta-tocopherol:mg/d
# vitamin c:mg/d
# thiamin:mg/d
# riboflavin:mg/d
# niacin (nicotinic acid) preformed:mg/d
# total niacin equivalent:NE/d
# pantothenic acid:mg/d
# vitamin b-6:mg/d
# biotin:ug/d
# total folacin:ug/d
# vitamin b-12:ug/d
# choline, total:mg/d
# vitamin k:ug/d
# folic acid:ug/d
# naturally occurring folate:ug/d
# dietary folate equivalents:ug/d
# betaine:mg/d
# tryptophan:g/d
# threonine:g/d
# isoleucine:g/d
# leucine:g/d
# lysine:g/d
# methionine:g/d
# cystine:g/d
# phenylalanine:g/d
# tyrosine:g/d
# valine:g/d
# arginine:g/d
# histidine:g/d
# alanine:g/d
# aspartic acid:g/d
# glutamic acid:g/d
# glycine:g/d
# proline:g/d
# serine:g/d
# hydroxyproline:g/d
# aspartame:mg/d
# alpha-tocopherol, added:mg/d
# vitamin b12, added:ug/d
# cholesterol:mg/d
# fatty acids, trans, total:g/d
# fatty acids, saturated, total:g/d
# fatty acids, saturated, 4:0, butanoic:g/d
# fatty acids, saturated, 6:0, hexanoic:g/d
# fatty acids, saturated, 8:0, octanoic:g/d
# fatty acids, saturated, 10:0, decanoic:g/d
# fatty acids, saturated, 12:0, dodecanoic:g/d
# fatty acids, saturated, 14:0, tetradecanoic:g/d
# fatty acids, saturated, 16:0, hexadecanoic:g/d
# fatty acids, saturated, 18:0, octadecanoic:g/d
# fatty acids, saturated, 20:0, eicosanoic:g/d
# fatty acids, monounsaturated, 18:1undifferentiated, octadecenoic:g/d
# fatty acids, polyunsaturated, 18:2undifferentiated, linoleic, octadecadienoic:g/d
# fatty acids, polyunsaturated, 18:3undifferentiated, linolenic, octadecatrienoic:g/d
# fatty acids, polyunsaturated, 20:4, eicosatetraenoic:g/d
# fatty acids, polyunsaturated, 22:6 n-3, docosahexaenoic (dha):g/d
# fatty acids, saturated, 22:0, docosanoic:g/d
# fatty acids, monounsaturated, 14:1, tetradecenoic:g/d
# fatty acids, monounsaturated, 16:1undifferentiated, hexadecenoic:g/d
# fatty acids, polyunsaturated, 18:4, octadecatetraenoic:g/d
# fatty acids, monounsaturated, 20:1, eicosenoic:g/d
# fatty acids, polyunsaturated, 20:5 n-3, eicosapentaenoic (epa):g/d
# fatty acids, monounsaturated, 22:1undifferentiated, docosenoic:g/d
# fatty acids, polyunsaturated, 22:5 n-3, docosapentaenoic (dpa):g/d
# total plant sterol:mg/d
# stigmasterol:mg/d
# campesterol:mg/d
# beta-sitosterol:mg/d
# fatty acids, monounsaturated, total:g/d
# fatty acids, polyunsaturated, total:g/d
# fatty acids, saturated, 15:0, pentadecanoic:g/d
# fatty acids, saturated, 17:0, heptadecanoic:g/d
# fatty acids, saturated, 24:0, tetracosanoic:g/d
# fatty acids, monounsaturated, 16:1t, hexadecenoic:g/d
# fatty acids, monounsaturated, 18:1t, octadecenoic:g/d
# fatty acids, monounsaturated, 22:1t, docosenoic:g/d
# fatty acids, polyunsaturated, 18:2i, linoleic, octadecadienoic:g/d
# fatty acids, polyunsaturated, 18:2t,t , octadecadienenoic:g/d
# fatty acids, polyunsaturated, conjugated, 18:2 cla, linoleic, octadecadienoic:g/d
# fatty acids, monounsaturated, 24:1c, tetracosenoic:g/d
# fatty acids, polyunsaturated, 20:2 c,c  eicosadienoic:g/d
# fatty acids, monounsaturated, 16:1c, hexadecenoic:g/d
# fatty acids, monounsaturated, 18:1c, octadecenoic:g/d
# fatty acids, polyunsaturated, 18:2 c,c n-6,  linoleic, octadecadienoic:g/d
# fatty acids, monounsaturated, 22:1c, docosenoic:g/d
# fatty acids, polyunsaturated, 18:3 c,c,c n-6, g-linolenic, octadecatrienoic:g/d
# fatty acids, monounsaturated, 17:1, heptadecenoic:g/d
# fatty acids, polyunsaturated, 20:3, eicosatrienoic:g/d
# fatty acids, total trans-monoenoic:g/d
# fatty acids, total trans-polyenoic:g/d
# fatty acids, saturated, 13:0 tridecanoic:g/d
# fatty acids, monounsaturated, 15:1, pentadecenoic:g/d
# total monosaccarides:g/d
# total disaccharides:g/d
# fatty acids, polyunsaturated, 18:3 c,c,c n-3  linolenic, octadecatrienoic:g/d
# fatty acids, polyunsaturated, 20:3 n-3 eicosatrienoic:g/d
# fatty acids, polyunsaturated, 20:3 n-6, eicosatrienoic:g/d
# fatty acids, polyunsaturated, 20:4 n-6, arachidonic:g/d
# fatty acids, polyunsaturated, 18:3i, linolenic, octadecatrienoic:g/d
# fatty acids, polyunsaturated, 21:5:g/d
# fatty acids, polyunsaturated, 22:4 n-6, docosatetraenoic:g/d
# fatty acids, monounsaturated,  24:1undifferentiated, tetracosenoic:g/d
# fatty acids, monounsaturated, 12:1, lauroleic:g/d
# fatty acids, polyunsaturated, 22:3,:g/d
# fatty acids, polyunsaturated, 22:2, docosadienoic:g/d
# fatty acids, polyunsaturated, total omega  n-3:g/d
# fatty acids, polyunsaturated, total omega   n-6:g/d

# %%
#concatenate 3 rdi lists
elems_vits_dict = {**rdi_elems_dict, **rdi_vits_dict}
rdi_dict = {**elems_vits_dict, **rdi_macros_dict}
for k,v in rdi_dict.items():
    print(f'{k}:{v}')
# Out:
# calcium:mg/d
# chromium:ug/d
# copper:ug/d
# fluoride:mg/d
# iodine:ug/d
# iron:mg/d
# magnesium:mg/d
# manganese:mg/d
# molybdenum:ug/d
# phosphorus:mg/d
# selenium:ug/d
# zinc:mg/d
# potassium:mg/d
# sodium:mg/d
# chloride:g/d
# vitamin a:ug/d
# vitamin c:mg/d
# vitamin d:ug/d
# vitamin e:mg/d
# vitamin k:ug/d
# thiamin:mg/d
# riboflavin:mg/d
# niacin:mg/d
# vitamin b6:mg/d
# folate:ug/d
# vitamin b12:ug/d
# pantothenic acid:mg/d
# biotin:ug/d
# choline:mg/d
# total water:l/d
# carbohydrates:g/d
# total fiber:g/d
# fat:g/d
# linoleic acid:g/d
# alpha-linolenic acid:g/d
# protein:g/d

# %%
# deepcopy dict
import copy
rdi_backup_dict = copy.deepcopy(rdi_dict)

# %%
# take out extra word like total
rdi_all_dict ={}
for nut, units in rdi_dict.items():
    # take out total and fix fibre misspellling
    if 'total' in nut: #total fiber, total fats
        new_nut = nut.replace('total', '').strip()
        rdi_all_dict[new_nut] = units
    else:
        rdi_all_dict[nut] = units
    
print(rdi_all_dict)
# Out:
# {'calcium': 'mg/d', 'chromium': 'ug/d', 'copper': 'ug/d', 'fluoride': 'mg/d', 'iodine': 'ug/d', 'iron': 'mg/d', 'magnesium': 'mg/d', 'manganese': 'mg/d', 'molybdenum': 'ug/d', 'phosphorus': 'mg/d', 'selenium': 'ug/d', 'zinc': 'mg/d', 'potassium': 'mg/d', 'sodium': 'mg/d', 'chloride': 'g/d', 'vitamin a': 'ug/d', 'vitamin c': 'mg/d', 'vitamin d': 'ug/d', 'vitamin e': 'mg/d', 'vitamin k': 'ug/d', 'thiamin': 'mg/d', 'riboflavin': 'mg/d', 'niacin': 'mg/d', 'vitamin b6': 'mg/d', 'folate': 'ug/d', 'vitamin b12': 'ug/d', 'pantothenic acid': 'mg/d', 'biotin': 'ug/d', 'choline': 'mg/d', 'water': 'l/d', 'carbohydrates': 'g/d', 'fiber': 'g/d', 'fat': 'g/d', 'linoleic acid': 'g/d', 'alpha-linolenic acid': 'g/d', 'protein': 'g/d'}

# %%
#cnf_nuts_dict vs rdi_units_dict
'''
#compare incoming cnf data with rdi benchmarks
compare the keys and include the matches in comparisons (missing sci-name nuts)
then compare the units to see which need conversions
exact_matches=[[{cnf:units},{rdi:units}]], convers_matches = [[{},{}]]
no_match= [cnf no rdi equivalent]
rdi_unused = []
'''
exacts=[]
converts =[]
cnf_unfound = []
rdi_matched = []
exact = False
convert= False
for nut, units in cnf_nuts_dict.items():
    for rdi_nut, rdi_units in rdi_all_dict.items():
        if nut in rdi_nut and units in rdi_units:
            exact=True
            exacts.append([{nut:units}, {rdi_nut:rdi_units}])
            rdi_matched.append({rdi_nut: rdi_units})
        elif nut in rdi_nut and units not in rdi_units:
            convert=True
            converts.append([{nut:units}, {rdi_nut:rdi_units}])
            rdi_matched.append({rdi_nut: rdi_units})

    if exact==False and convert==False:
        cnf_unfound.append({nut:units})
    exact=False
    convert=False

#also need which rdi are not in cnf

print(len(exacts), exacts)
print(f'\n\nconvert: {len(converts)}\n{converts}')
print(f'len rdi_all_dict: {len(rdi_all_dict)}')
print(f'\n\nrdi matched: {len(rdi_matched)}\n{rdi_matched}')
print(f'\n\nno match:{len(cnf_unfound)}\n{cnf_unfound}')
# Out:
# 19 [[{'protein': 'g/d'}, {'protein': 'g/d'}], [{'fat': 'g/d'}, {'fat': 'g/d'}], [{'carbohydrate': 'g/d'}, {'carbohydrates': 'g/d'}], [{'fiber': 'g/d'}, {'fiber': 'g/d'}], [{'calcium': 'mg/d'}, {'calcium': 'mg/d'}], [{'iron': 'mg/d'}, {'iron': 'mg/d'}], [{'magnesium': 'mg/d'}, {'magnesium': 'mg/d'}], [{'phosphorus': 'mg/d'}, {'phosphorus': 'mg/d'}], [{'potassium': 'mg/d'}, {'potassium': 'mg/d'}], [{'sodium': 'mg/d'}, {'sodium': 'mg/d'}], [{'zinc': 'mg/d'}, {'zinc': 'mg/d'}], [{'manganese': 'mg/d'}, {'manganese': 'mg/d'}], [{'selenium': 'ug/d'}, {'selenium': 'ug/d'}], [{'vitamin c': 'mg/d'}, {'vitamin c': 'mg/d'}], [{'thiamin': 'mg/d'}, {'thiamin': 'mg/d'}], [{'riboflavin': 'mg/d'}, {'riboflavin': 'mg/d'}], [{'pantothenic acid': 'mg/d'}, {'pantothenic acid': 'mg/d'}], [{'biotin': 'ug/d'}, {'biotin': 'ug/d'}], [{'vitamin k': 'ug/d'}, {'vitamin k': 'ug/d'}]]
#
#
# convert: 1
# [[{'copper': 'mg/d'}, {'copper': 'ug/d'}]]
# len rdi_all_dict: 36
#
#
# rdi matched: 20
# [{'protein': 'g/d'}, {'fat': 'g/d'}, {'carbohydrates': 'g/d'}, {'fiber': 'g/d'}, {'calcium': 'mg/d'}, {'iron': 'mg/d'}, {'magnesium': 'mg/d'}, {'phosphorus': 'mg/d'}, {'potassium': 'mg/d'}, {'sodium': 'mg/d'}, {'zinc': 'mg/d'}, {'copper': 'ug/d'}, {'manganese': 'mg/d'}, {'selenium': 'ug/d'}, {'vitamin c': 'mg/d'}, {'thiamin': 'mg/d'}, {'riboflavin': 'mg/d'}, {'pantothenic acid': 'mg/d'}, {'biotin': 'ug/d'}, {'vitamin k': 'ug/d'}]
#
#
# no match:132
# [{'ash, total': 'g/d'}, {'energy (kilocalories)': 'kCal/d'}, {'starch': 'g/d'}, {'sucrose': 'g/d'}, {'glucose': 'g/d'}, {'fructose': 'g/d'}, {'lactose': 'g/d'}, {'maltose': 'g/d'}, {'alcohol': 'g/d'}, {'oxalic acid': 'mg/d'}, {'moisture': 'g/d'}, {'mannitol': 'g/d'}, {'sorbitol': 'g/d'}, {'caffeine': 'mg/d'}, {'theobromine': 'mg/d'}, {'energy (kilojoules)': 'kJ/d'}, {'sugars, total': 'g/d'}, {'galactose': 'g/d'}, {'retinol': 'ug/d'}, {'retinol activity equivalents': 'ug/d'}, {'beta carotene': 'ug/d'}, {'alpha carotene': 'ug/d'}, {'alpha-tocopherol': 'mg/d'}, {'vitamin d (international units)': 'IU/d'}, {'vitamin d2, ergocalciferol': 'ug/d'}, {'vitamin d (d2 + d3)': 'ug/d'}, {'beta cryptoxanthin': 'ug/d'}, {'lycopene': 'ug/d'}, {'lutein and zeaxanthin': 'ug/d'}, {'beta-tocopherol': 'mg/d'}, {'gamma-tocopherol': 'mg/d'}, {'delta-tocopherol': 'mg/d'}, {'niacin (nicotinic acid) preformed': 'mg/d'}, {'total niacin equivalent': 'NE/d'}, {'vitamin b-6': 'mg/d'}, {'total folacin': 'ug/d'}, {'vitamin b-12': 'ug/d'}, {'choline, total': 'mg/d'}, {'folic acid': 'ug/d'}, {'naturally occurring folate': 'ug/d'}, {'dietary folate equivalents': 'ug/d'}, {'betaine': 'mg/d'}, {'tryptophan': 'g/d'}, {'threonine': 'g/d'}, {'isoleucine': 'g/d'}, {'leucine': 'g/d'}, {'lysine': 'g/d'}, {'methionine': 'g/d'}, {'cystine': 'g/d'}, {'phenylalanine': 'g/d'}, {'tyrosine': 'g/d'}, {'valine': 'g/d'}, {'arginine': 'g/d'}, {'histidine': 'g/d'}, {'alanine': 'g/d'}, {'aspartic acid': 'g/d'}, {'glutamic acid': 'g/d'}, {'glycine': 'g/d'}, {'proline': 'g/d'}, {'serine': 'g/d'}, {'hydroxyproline': 'g/d'}, {'aspartame': 'mg/d'}, {'alpha-tocopherol, added': 'mg/d'}, {'vitamin b12, added': 'ug/d'}, {'cholesterol': 'mg/d'}, {'fatty acids, trans, total': 'g/d'}, {'fatty acids, saturated, total': 'g/d'}, {'fatty acids, saturated, 4:0, butanoic': 'g/d'}, {'fatty acids, saturated, 6:0, hexanoic': 'g/d'}, {'fatty acids, saturated, 8:0, octanoic': 'g/d'}, {'fatty acids, saturated, 10:0, decanoic': 'g/d'}, {'fatty acids, saturated, 12:0, dodecanoic': 'g/d'}, {'fatty acids, saturated, 14:0, tetradecanoic': 'g/d'}, {'fatty acids, saturated, 16:0, hexadecanoic': 'g/d'}, {'fatty acids, saturated, 18:0, octadecanoic': 'g/d'}, {'fatty acids, saturated, 20:0, eicosanoic': 'g/d'}, {'fatty acids, monounsaturated, 18:1undifferentiated, octadecenoic': 'g/d'}, {'fatty acids, polyunsaturated, 18:2undifferentiated, linoleic, octadecadienoic': 'g/d'}, {'fatty acids, polyunsaturated, 18:3undifferentiated, linolenic, octadecatrienoic': 'g/d'}, {'fatty acids, polyunsaturated, 20:4, eicosatetraenoic': 'g/d'}, {'fatty acids, polyunsaturated, 22:6 n-3, docosahexaenoic (dha)': 'g/d'}, {'fatty acids, saturated, 22:0, docosanoic': 'g/d'}, {'fatty acids, monounsaturated, 14:1, tetradecenoic': 'g/d'}, {'fatty acids, monounsaturated, 16:1undifferentiated, hexadecenoic': 'g/d'}, {'fatty acids, polyunsaturated, 18:4, octadecatetraenoic': 'g/d'}, {'fatty acids, monounsaturated, 20:1, eicosenoic': 'g/d'}, {'fatty acids, polyunsaturated, 20:5 n-3, eicosapentaenoic (epa)': 'g/d'}, {'fatty acids, monounsaturated, 22:1undifferentiated, docosenoic': 'g/d'}, {'fatty acids, polyunsaturated, 22:5 n-3, docosapentaenoic (dpa)': 'g/d'}, {'total plant sterol': 'mg/d'}, {'stigmasterol': 'mg/d'}, {'campesterol': 'mg/d'}, {'beta-sitosterol': 'mg/d'}, {'fatty acids, monounsaturated, total': 'g/d'}, {'fatty acids, polyunsaturated, total': 'g/d'}, {'fatty acids, saturated, 15:0, pentadecanoic': 'g/d'}, {'fatty acids, saturated, 17:0, heptadecanoic': 'g/d'}, {'fatty acids, saturated, 24:0, tetracosanoic': 'g/d'}, {'fatty acids, monounsaturated, 16:1t, hexadecenoic': 'g/d'}, {'fatty acids, monounsaturated, 18:1t, octadecenoic': 'g/d'}, {'fatty acids, monounsaturated, 22:1t, docosenoic': 'g/d'}, {'fatty acids, polyunsaturated, 18:2i, linoleic, octadecadienoic': 'g/d'}, {'fatty acids, polyunsaturated, 18:2t,t , octadecadienenoic': 'g/d'}, {'fatty acids, polyunsaturated, conjugated, 18:2 cla, linoleic, octadecadienoic': 'g/d'}, { ...

# %%
#find which rdi did not match
rdi_unfound = {}
found = False
for name, units in rdi_all_dict.items():
    for matches in rdi_matched:
        for nut, measure in matches.items():
            if name in nut:
                found=True
    if found==False:
        rdi_unfound[name]=units
    found=False

print(rdi_unfound)
# Out:
# {'chromium': 'ug/d', 'fluoride': 'mg/d', 'iodine': 'ug/d', 'molybdenum': 'ug/d', 'chloride': 'g/d', 'vitamin a': 'ug/d', 'vitamin d': 'ug/d', 'vitamin e': 'mg/d', 'niacin': 'mg/d', 'vitamin b6': 'mg/d', 'folate': 'ug/d', 'vitamin b12': 'ug/d', 'choline': 'mg/d', 'water': 'l/d', 'linoleic acid': 'g/d', 'alpha-linolenic acid': 'g/d'}

# %%
#print(cnf_unfound)
cnf_missing = {}
#convert to dict from list of dicts
for pair in cnf_unfound:
    for k,v in pair.items():
        cnf_missing[k]=v
print(cnf_missing)
# Out:
# {'ash, total': 'g/d', 'energy (kilocalories)': 'kCal/d', 'starch': 'g/d', 'sucrose': 'g/d', 'glucose': 'g/d', 'fructose': 'g/d', 'lactose': 'g/d', 'maltose': 'g/d', 'alcohol': 'g/d', 'oxalic acid': 'mg/d', 'moisture': 'g/d', 'mannitol': 'g/d', 'sorbitol': 'g/d', 'caffeine': 'mg/d', 'theobromine': 'mg/d', 'energy (kilojoules)': 'kJ/d', 'sugars, total': 'g/d', 'galactose': 'g/d', 'retinol': 'ug/d', 'retinol activity equivalents': 'ug/d', 'beta carotene': 'ug/d', 'alpha carotene': 'ug/d', 'alpha-tocopherol': 'mg/d', 'vitamin d (international units)': 'IU/d', 'vitamin d2, ergocalciferol': 'ug/d', 'vitamin d (d2 + d3)': 'ug/d', 'beta cryptoxanthin': 'ug/d', 'lycopene': 'ug/d', 'lutein and zeaxanthin': 'ug/d', 'beta-tocopherol': 'mg/d', 'gamma-tocopherol': 'mg/d', 'delta-tocopherol': 'mg/d', 'niacin (nicotinic acid) preformed': 'mg/d', 'total niacin equivalent': 'NE/d', 'vitamin b-6': 'mg/d', 'total folacin': 'ug/d', 'vitamin b-12': 'ug/d', 'choline, total': 'mg/d', 'folic acid': 'ug/d', 'naturally occurring folate': 'ug/d', 'dietary folate equivalents': 'ug/d', 'betaine': 'mg/d', 'tryptophan': 'g/d', 'threonine': 'g/d', 'isoleucine': 'g/d', 'leucine': 'g/d', 'lysine': 'g/d', 'methionine': 'g/d', 'cystine': 'g/d', 'phenylalanine': 'g/d', 'tyrosine': 'g/d', 'valine': 'g/d', 'arginine': 'g/d', 'histidine': 'g/d', 'alanine': 'g/d', 'aspartic acid': 'g/d', 'glutamic acid': 'g/d', 'glycine': 'g/d', 'proline': 'g/d', 'serine': 'g/d', 'hydroxyproline': 'g/d', 'aspartame': 'mg/d', 'alpha-tocopherol, added': 'mg/d', 'vitamin b12, added': 'ug/d', 'cholesterol': 'mg/d', 'fatty acids, trans, total': 'g/d', 'fatty acids, saturated, total': 'g/d', 'fatty acids, saturated, 4:0, butanoic': 'g/d', 'fatty acids, saturated, 6:0, hexanoic': 'g/d', 'fatty acids, saturated, 8:0, octanoic': 'g/d', 'fatty acids, saturated, 10:0, decanoic': 'g/d', 'fatty acids, saturated, 12:0, dodecanoic': 'g/d', 'fatty acids, saturated, 14:0, tetradecanoic': 'g/d', 'fatty acids, saturated, 16:0, hexadecanoic': 'g/d', 'fatty acids, saturated, 18:0, octadecanoic': 'g/d', 'fatty acids, saturated, 20:0, eicosanoic': 'g/d', 'fatty acids, monounsaturated, 18:1undifferentiated, octadecenoic': 'g/d', 'fatty acids, polyunsaturated, 18:2undifferentiated, linoleic, octadecadienoic': 'g/d', 'fatty acids, polyunsaturated, 18:3undifferentiated, linolenic, octadecatrienoic': 'g/d', 'fatty acids, polyunsaturated, 20:4, eicosatetraenoic': 'g/d', 'fatty acids, polyunsaturated, 22:6 n-3, docosahexaenoic (dha)': 'g/d', 'fatty acids, saturated, 22:0, docosanoic': 'g/d', 'fatty acids, monounsaturated, 14:1, tetradecenoic': 'g/d', 'fatty acids, monounsaturated, 16:1undifferentiated, hexadecenoic': 'g/d', 'fatty acids, polyunsaturated, 18:4, octadecatetraenoic': 'g/d', 'fatty acids, monounsaturated, 20:1, eicosenoic': 'g/d', 'fatty acids, polyunsaturated, 20:5 n-3, eicosapentaenoic (epa)': 'g/d', 'fatty acids, monounsaturated, 22:1undifferentiated, docosenoic': 'g/d', 'fatty acids, polyunsaturated, 22:5 n-3, docosapentaenoic (dpa)': 'g/d', 'total plant sterol': 'mg/d', 'stigmasterol': 'mg/d', 'campesterol': 'mg/d', 'beta-sitosterol': 'mg/d', 'fatty acids, monounsaturated, total': 'g/d', 'fatty acids, polyunsaturated, total': 'g/d', 'fatty acids, saturated, 15:0, pentadecanoic': 'g/d', 'fatty acids, saturated, 17:0, heptadecanoic': 'g/d', 'fatty acids, saturated, 24:0, tetracosanoic': 'g/d', 'fatty acids, monounsaturated, 16:1t, hexadecenoic': 'g/d', 'fatty acids, monounsaturated, 18:1t, octadecenoic': 'g/d', 'fatty acids, monounsaturated, 22:1t, docosenoic': 'g/d', 'fatty acids, polyunsaturated, 18:2i, linoleic, octadecadienoic': 'g/d', 'fatty acids, polyunsaturated, 18:2t,t , octadecadienenoic': 'g/d', 'fatty acids, polyunsaturated, conjugated, 18:2 cla, linoleic, octadecadienoic': 'g/d', 'fatty acids, monounsaturated, 24:1c, tetracosenoic': 'g/d', 'fatty acids, polyunsaturated, 20:2 c,c  eicosadienoic': 'g/d', 'fatty acids, monounsaturated, 16:1c, hexadecenoic': 'g/d', 'fatty acids, monounsatu ...

# %% [markdown]
# # waypoint, found more rdi in cnf, previous was cnf in rdi but cnf names are longer

# %%
#compare rdi_unfound with cnf_missing
#find which rdi did not match
matches = []
no_matches = []
found = False
for name, units in rdi_unfound.items():
    for miss, meas in cnf_missing.items():
        if name in miss:
            found = True
            matches.append([{name:units},{miss:meas}])
    if found==False:
        no_matches.append({name:units})
    found=False

print(f'matches:\n{matches}\nno matches:\n{no_matches}')
# Out:
# matches:
# [[{'vitamin d': 'ug/d'}, {'vitamin d (international units)': 'IU/d'}], [{'vitamin d': 'ug/d'}, {'vitamin d2, ergocalciferol': 'ug/d'}], [{'vitamin d': 'ug/d'}, {'vitamin d (d2 + d3)': 'ug/d'}], [{'niacin': 'mg/d'}, {'niacin (nicotinic acid) preformed': 'mg/d'}], [{'niacin': 'mg/d'}, {'total niacin equivalent': 'NE/d'}], [{'folate': 'ug/d'}, {'naturally occurring folate': 'ug/d'}], [{'folate': 'ug/d'}, {'dietary folate equivalents': 'ug/d'}], [{'vitamin b12': 'ug/d'}, {'vitamin b12, added': 'ug/d'}], [{'choline': 'mg/d'}, {'choline, total': 'mg/d'}]]
# no matches:
# [{'chromium': 'ug/d'}, {'fluoride': 'mg/d'}, {'iodine': 'ug/d'}, {'molybdenum': 'ug/d'}, {'chloride': 'g/d'}, {'vitamin a': 'ug/d'}, {'vitamin e': 'mg/d'}, {'vitamin b6': 'mg/d'}, {'water': 'l/d'}, {'linoleic acid': 'g/d'}, {'alpha-linolenic acid': 'g/d'}]

# %% [markdown]
# no matches: <br>
#
# {'chromium': 'ug/d'}, <br>
# {'fluoride': 'mg/d'}, <br>
# {'iodine': 'ug/d'}, <br>
# {'molybdenum': 'ug/d'}, <br>
# {'chloride': 'g/d'}, <br>
# {'water': 'l/d'}, <br>
# <br>
# {'vitamin a': 'ug/d'} = 'retinol': 'ug/d' <br>
# {'vitamin e': 'mg/d'}, = 'alpha-tocopherol': 'mg/d' <br>
# {'vitamin b6': 'mg/d'}, = 'vitamin b-6': 'mg/d' <br>
# {'linoleic acid': 'g/d'}, = there are 4 if just 'linoleic' so sum?<br>
# {'alpha-linolenic acid': 'g/d'} = also 4 if just 'linolenic' <br>

# %% [markdown]
# # Done here, below is other stuff

# %% [markdown]
# ### make cnf_elems_dict, cnf_vits_dict, cnf_macros_dict

# %%
cnf_elems_dict, cnf_vits_dict, cnf_macros_dict = {}, {}, {}
for match in exacts:
    cnf = match[0]

    cnf_nut = list(cnf.keys())[0]
    cnf_units = list(cnf.values())[0]
    # print(cnf_nut, cnf_units)
    # rdi = match[1]
    # rdi_nut = list(rdi.keys())[0]
    # rdi_units = list(rdi.values())[0]
    for rdi_nut, _ in rdi_elems_dict.items():
        if cnf_nut in rdi_nut:
            cnf_elems_dict[cnf_nut] = cnf_units
            continue
    for rdi_nut, _ in rdi_vits_dict.items():
        if cnf_nut in rdi_nut:
            cnf_vits_dict[cnf_nut] = cnf_units
            continue
    for rdi_nut, _ in rdi_macros_dict.items():
        if cnf_nut in rdi_nut:
            cnf_macros_dict[cnf_nut] = cnf_units
            continue

print(len(cnf_elems_dict), len(cnf_vits_dict), len(cnf_macros_dict))
for nut, unit in cnf_elems_dict.items():
    print(f'{nut}:{unit}')
for nut, unit in cnf_vits_dict.items():
    print(f'{nut}:{unit}')
for nut, unit in cnf_macros_dict.items():
    print(f'{nut}:{unit}')
# Out:
# 9 6 4
# calcium:mg/d
# iron:mg/d
# magnesium:mg/d
# phosphorus:mg/d
# potassium:mg/d
# sodium:mg/d
# zinc:mg/d
# manganese:mg/d
# selenium:ug/d
# vitamin c:mg/d
# thiamin:mg/d
# riboflavin:mg/d
# pantothenic acid:mg/d
# biotin:ug/d
# vitamin k:ug/d
# protein:g/d
# fat:g/d
# carbohydrate:g/d
# fiber:g/d

# %%
cnf_elems_dicts, cnf_vits_dicts, cnf_macros_dicts=[], [], []

for match in exacts:
    cnf = match[0]
    
    cnf_nut = list(cnf.keys())[0]
    cnf_units = list(cnf.values())[0]
    #print(cnf_nut, cnf_units)
    rdi = match[1]
    rdi_nut = list(rdi.keys())[0]
    rdi_units = list(rdi.values())[0]
    for rdi_n, _ in rdi_elems_dict.items():
        if cnf_nut in rdi_n:
            cnf_elems_dicts.append([{cnf_nut:cnf_units},{rdi_nut:rdi_units}]) 
            continue
    for rdi_n, _ in rdi_vits_dict.items():
        if cnf_nut in rdi_n:
            cnf_vits_dicts.append([{cnf_nut:cnf_units}, {rdi_nut:rdi_units}])
            continue
    for rdi_n, _ in rdi_macros_dict.items():
        if cnf_nut in rdi_n:
            cnf_macros_dicts.append([{cnf_nut:cnf_units},{rdi_nut:rdi_units}])
            continue

print(len(cnf_elems_dicts), len(cnf_vits_dicts), len(cnf_macros_dicts))
print(cnf_elems_dicts, cnf_vits_dicts, cnf_macros_dicts)
# Out:
# 9 6 4
# [[{'calcium': 'mg/d'}, {'calcium': 'mg/d'}], [{'iron': 'mg/d'}, {'iron': 'mg/d'}], [{'magnesium': 'mg/d'}, {'magnesium': 'mg/d'}], [{'phosphorus': 'mg/d'}, {'phosphorus': 'mg/d'}], [{'potassium': 'mg/d'}, {'potassium': 'mg/d'}], [{'sodium': 'mg/d'}, {'sodium': 'mg/d'}], [{'zinc': 'mg/d'}, {'zinc': 'mg/d'}], [{'manganese': 'mg/d'}, {'manganese': 'mg/d'}], [{'selenium': 'ug/d'}, {'selenium': 'ug/d'}]] [[{'vitamin c': 'mg/d'}, {'vitamin c': 'mg/d'}], [{'thiamin': 'mg/d'}, {'thiamin': 'mg/d'}], [{'riboflavin': 'mg/d'}, {'riboflavin': 'mg/d'}], [{'pantothenic acid': 'mg/d'}, {'pantothenic acid': 'mg/d'}], [{'biotin': 'ug/d'}, {'biotin': 'ug/d'}], [{'vitamin k': 'ug/d'}, {'vitamin k': 'ug/d'}]] [[{'protein': 'g/d'}, {'protein': 'g/d'}], [{'fat': 'g/d'}, {'fat': 'g/d'}], [{'carbohydrate': 'g/d'}, {'carbohydrate': 'g/d'}], [{'fiber': 'g/d'}, {'fiber': 'g/d'}]]

# %%
cnf_elems_dict, cnf_vits_dict, cnf_macros_dict={}, {}, {}
# 9,6,2, items for 17
for match in exacts:
    cnf = match[0]
    
    cnf_nut = list(cnf.keys())[0]
    cnf_units = list(cnf.values())[0]
    #print(cnf_nut, cnf_units)
    rdi = match[1]
    rdi_nut = list(rdi.keys())[0]
    rdi_units = list(rdi.values())[0]
    #print(rdi_nut, rdi_units)
    #print(list(rdi_elems_dict.keys()))
    if rdi_nut in list(rdi_elems_dict.keys()):
        cnf_elems_dict[cnf_nut] = cnf_units
    elif rdi_nut in list(rdi_vits_dict.keys()):
        cnf_vits_dict[cnf_nut] = cnf_units
        #continue
    elif rdi_nut in list(rdi_macros_dict.keys()):
        cnf_macros_dict[cnf_nut] = cnf_units
        #continue
print(len(cnf_elems_dict), len(cnf_vits_dict), len(cnf_macros_dict))
for nut, unit in cnf_elems_dict.items():
    print(f'{nut}:{unit}')
for nut, unit in cnf_vits_dict.items():
    print(f'{nut}:{unit}')
for nut, unit in cnf_macros_dict.items():
    print(f'{nut}:{unit}')
# Out:
# 9 6 2
# calcium:mg/d
# iron:mg/d
# magnesium:mg/d
# phosphorus:mg/d
# potassium:mg/d
# sodium:mg/d
# zinc:mg/d
# manganese:mg/d
# selenium:ug/d
# vitamin c:mg/d
# thiamin:mg/d
# riboflavin:mg/d
# pantothenic acid:mg/d
# biotin:ug/d
# vitamin k:ug/d
# protein:g/d
# fat:g/d
