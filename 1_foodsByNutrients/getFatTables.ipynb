# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
"""
get all links then follow all links and get tables
"""

import pandas as pd
from bs4 import BeautifulSoup
import requests
import lxml.html as lh
#from langdetect import detect


url = "https://www.webmd.com/diet/features/estimated-calorie-requirement"
url = "https://health.gov/our-work/food-nutrition/2015-2020-dietary-guidelines/guidelines/appendix-2"
soup = BeautifulSoup(requests.get(url).content, 'html.parser')

tables = soup.find_all('table')
tables_arr = []


#print(soup)
print(tables[0])
# Out:
# <table data-tablesaw-minimap="" data-tablesaw-mode="swipe">
# <caption class="first-row">
# <strong>MALES</strong>
# </caption>
# <thead>
# <tr>
# <th data-tablesaw-priority="persist" scope="col"><strong>AGE</strong></th>
# <th scope="col">Sedentary<a href="#footnote-1" id="footnote-ref1"><sup>[a]</sup></a></th>
# <th scope="col">Moderately<br/>active<a href="#footnote-2" id="footnote-ref2"><sup>[b]</sup></a></th>
# <th scope="col">Active<a href="#footnote-3" id="footnote-ref3"><sup>[c]</sup></a></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th class="data-th" scope="row">2</th>
# <td class="val">1,000</td>
# <td class="val">1,000</td>
# <td class="val">1,000</td>
# </tr>
# <tr>
# <th class="data-th" scope="row">3</th>
# <td class="val">1,000</td>
# <td class="val">1,400</td>
# <td class="val">1,400</td>
# </tr>
# <tr>
# <th class="data-th" scope="row">4</th>
# <td class="val">1,200</td>
# <td class="val">1,400</td>
# <td class="val">1,600</td>
# </tr>
# <tr>
# ...

# %%
rows1 = []
rows2 = []
i = 0
for table in tables:
    for row in table.select('table tr'):
        tds = [td.get_text(strip=True) for td 
               in row.select('td, th')]
        if i ==0:
            rows1.append(tds)
        else:
            rows2.append(tds)
    i+=1
    
print(rows1, "\n", rows2)
# Out:
# [['AGE', 'Sedentary[a]', 'Moderatelyactive[b]', 'Active[c]'], ['2', '1,000', '1,000', '1,000'], ['3', '1,000', '1,400', '1,400'], ['4', '1,200', '1,400', '1,600'], ['5', '1,200', '1,400', '1,600'], ['6', '1,400', '1,600', '1,800'], ['7', '1,400', '1,600', '1,800'], ['8', '1,400', '1,600', '2,000'], ['9', '1,600', '1,800', '2,000'], ['10', '1,600', '1,800', '2,200'], ['11', '1,800', '2,000', '2,200'], ['12', '1,800', '2,200', '2,400'], ['13', '2,000', '2,200', '2,600'], ['14', '2,000', '2,400', '2,800'], ['15', '2,200', '2,600', '3,000'], ['16', '2,400', '2,800', '3,200'], ['17', '2,400', '2,800', '3,200'], ['18', '2,400', '2,800', '3,200'], ['19-20', '2,600', '2,800', '3,000'], ['21-25', '2,400', '2,800', '3,000'], ['26-30', '2,400', '2,600', '3,000'], ['31-35', '2,400', '2,600', '3,000'], ['36-40', '2,400', '2,600', '2,800'], ['41-45', '2,200', '2,600', '2,800'], ['46-50', '2,200', '2,400', '2,800'], ['51-55', '2,200', '2,400', '2,800'], ['56-60', '2,200', '2,400', '2,600'], ['61-65
# ...

# %%
# first elem is columns
cols = rows1[0]
cols = ['age', 'sedentary', 'moderately_active', 'active']

# %%
males_dict = []
for i in range (1, len(rows1)):
    males_dict.append({cols[0]: rows1[i][0],
                            cols[1]: rows1[i][1],
                            cols[2]: rows1[i][2],
                            cols[3]: rows1[i][3]})

males_df = pd.DataFrame(males_dict)

males_df
# Out:
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,400  1,400
# 2           4     1,200             1,400  1,600
# 3           5     1,200             1,400  1,600
# 4           6     1,400             1,600  1,800
# 5           7     1,400             1,600  1,800
# 6           8     1,400             1,600  2,000
# 7           9     1,600             1,800  2,000
# 8          10     1,600             1,800  2,200
# 9          11     1,800             2,000  2,200
# 10         12     1,800             2,200  2,400
# 11         13     2,000             2,200  2,600
# 12         14     2,000             2,400  2,800
# 13         15     2,200             2,600  3,000
# 14         16     2,400             2,800  3,200
# 15         17     2,400             2,800  3,200
# 16         18     2,400             2,800  3,200
# 17      19-20     2,600             2,800  3,000
# ...

# %%
m_df = pd.DataFrame.from_dict(males_dict)
m_df
# Out:
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,400  1,400
# 2           4     1,200             1,400  1,600
# 3           5     1,200             1,400  1,600
# 4           6     1,400             1,600  1,800
# 5           7     1,400             1,600  1,800
# 6           8     1,400             1,600  2,000
# 7           9     1,600             1,800  2,000
# 8          10     1,600             1,800  2,200
# 9          11     1,800             2,000  2,200
# 10         12     1,800             2,200  2,400
# 11         13     2,000             2,200  2,600
# 12         14     2,000             2,400  2,800
# 13         15     2,200             2,600  3,000
# 14         16     2,400             2,800  3,200
# 15         17     2,400             2,800  3,200
# 16         18     2,400             2,800  3,200
# 17      19-20     2,600             2,800  3,000
# ...

# %%
ma_df = pd.DataFrame.from_records(males_dict)
ma_df
# Out:
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,400  1,400
# 2           4     1,200             1,400  1,600
# 3           5     1,200             1,400  1,600
# 4           6     1,400             1,600  1,800
# 5           7     1,400             1,600  1,800
# 6           8     1,400             1,600  2,000
# 7           9     1,600             1,800  2,000
# 8          10     1,600             1,800  2,200
# 9          11     1,800             2,000  2,200
# 10         12     1,800             2,200  2,400
# 11         13     2,000             2,200  2,600
# 12         14     2,000             2,400  2,800
# 13         15     2,200             2,600  3,000
# 14         16     2,400             2,800  3,200
# 15         17     2,400             2,800  3,200
# 16         18     2,400             2,800  3,200
# 17      19-20     2,600             2,800  3,000
# ...

# %%
#females
females_dict = []
for i in range (1, len(rows2)):
    females_dict.append({cols[0]: rows2[i][0],
                            cols[1]: rows2[i][1],
                            cols[2]: rows2[i][2],
                            cols[3]: rows2[i][3]})

females_df = pd.DataFrame(females_dict)

females_df
# Out:
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,200  1,400
# 2           4     1,200             1,400  1,400
# 3           5     1,200             1,400  1,600
# 4           6     1,200             1,400  1,600
# 5           7     1,200             1,600  1,800
# 6           8     1,400             1,600  1,800
# 7           9     1,400             1,600  1,800
# 8          10     1,400             1,800  2,000
# 9          11     1,600             1,800  2,000
# 10         12     1,600             2,000  2,200
# 11         13     1,600             2,000  2,200
# 12         14     1,800             2,000  2,400
# 13         15     1,800             2,000  2,400
# 14         16     1,800             2,000  2,400
# 15         17     1,800             2,000  2,400
# 16         18     1,800             2,000  2,400
# 17      19-20     2,000             2,200  2,400
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://root:tennis33@localhost/rdi_db?charset=utf8mb4")

# %%
#df.to_sql was deleted

# %% [markdown]
# # Read in from mysql

# %%
males_table_name = 'males_calories'

sql = "SELECT * from " + males_table_name

males_df = pd.read_sql_query(sql, engine)

females_table = 'females_calories'

sql2 = "SELECT * from " + females_table

females_df = pd.read_sql_query(sql2, engine)

# %%
females_df
# Out:
#           age sedentary moderately_active active
# 0           2     1,000             1,000  1,000
# 1           3     1,000             1,200  1,400
# 2           4     1,200             1,400  1,400
# 3           5     1,200             1,400  1,600
# 4           6     1,200             1,400  1,600
# 5           7     1,200             1,600  1,800
# 6           8     1,400             1,600  1,800
# 7           9     1,400             1,600  1,800
# 8          10     1,400             1,800  2,000
# 9          11     1,600             1,800  2,000
# 10         12     1,600             2,000  2,200
# 11         13     1,600             2,000  2,200
# 12         14     1,800             2,000  2,400
# 13         15     1,800             2,000  2,400
# 14         16     1,800             2,000  2,400
# 15         17     1,800             2,000  2,400
# 16         18     1,800             2,000  2,400
# 17      19-20     2,000             2,200  2,400
# ...

# %%
val = females_df['sedentary'].iloc[-1]
print(int(val.replace(",", "")))
row = females_df.iloc[-1]
print(row)
# Out:
# 1600
# age                  76 and up
# sedentary                1,600
# moderately_active        1,800
# active                   2,000
# Name: 29, dtype: object

# %%
row = males_df[males_df['age'] == '76 and up']
print(row)
#row = males_df.loc['76 and up', 'active']
val = row['active']
val
# Out:
# Empty DataFrame
# Columns: [age, sedentary, moderately_active, active]
# Index: []
# Series([], Name: active, dtype: object)

# %%
males_df.dtypes
age = 52
activity_lvl = 'active'

#portion = males_df.iloc[17:, :]

the_idx = -1 
for idx, row in males_df.iterrows():
    if "-" in row['age']:
        age_grp = row['age'].split('-')
        age_grp = [int(x) for x in age_grp]
        low = age_grp[0]
        high = age_grp[1]
        if low <= age <= high:
            the_idx = idx
            val = males_df.loc[idx, activity_lvl]
            break

print(the_idx, int(val.replace(",", "")))
# Out:
# 24 2800

# %%
idx= males_df.index[males_df['age']==str(18)][0]
val = males_df.loc[idx, 'active']
val
# Out:
# '3,200'
